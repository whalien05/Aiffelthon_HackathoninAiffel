# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Aiffelthon
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Aiffelthon

# %%
# train_super_path = '/content/drive/MyDrive/Aiffelthon/mmrotate/data/fair1m2.0/0829_train_super/'
# train_folder_list =[]

# %%
# import os
# train_super_list = os.listdir(train_super_path)
# train_super_list

# %%
# get_one = train_super_list + [0]

# file = open( train_super_path+[0], "r")
# strings = file.readlines()
# print(strings)
# file.close()

# %%
# train_super_path = '/content/drive/MyDrive/Aiffelthon/eda/tif_file_class_frequency/train_part1_tif_class_frequency.csv'

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Aiffelthon'

# %%
# %cd /content/drive/MyDrive/Aiffelthon/eda/tif_file_class_frequency/class_frequencey/
# Out:
# /content/drive/MyDrive/Aiffelthon/eda/tif_file_class_frequency/class_frequencey

# %%
import pandas as pd

data = pd.read_csv("train_part1_tif_class_frequency.csv")
data2 = pd.read_csv("train_part2_tif_class_frequency.csv")
data3 = pd.read_csv("validation_tif_class_frequency.csv")

data.head()
# Out:
#     File  Vehicle  Airplane  Ship
# 0  0.tif        0         0     3
# 1  1.tif       68         0     0
# 2  2.tif        0         3     0
# 3  3.tif        0         0     0
# 4  4.tif        0         2     0

# %%
data3.head()
# Out:
#     File  Vehicle  Airplane  Ship
# 0  0.tif        0         0     1
# 1  1.tif       20         0     0
# 2  2.tif        0         0     0
# 3  3.tif        0         0     3
# 4  4.tif       44         0     0

# %%
# 각 row의 column 마다 접근할 수 있음
data.iloc[1][1]
# Out:
# 68

# %%
len(data)
# Out:
# 1732

# %%
only_vehicle = [] 
only_airplane=[]
only_ship=[]

# %%
for i in range(len(data)):
  if data.iloc[i][1] != 0 and data.iloc[i][2] == 0 and data.iloc[i][3] ==0 :
    only_vehicle.append(data.iloc[i])
# break

# %%
for i in range(len(data)):
  if data.iloc[i][2] != 0 and data.iloc[i][1] == 0 and data.iloc[i][3] ==0 :
    only_airplane.append(data.iloc[i])

# %%
for i in range(len(data)):
  if data.iloc[i][3] != 0 and data.iloc[i][1] == 0 and data.iloc[i][2] ==0 :
    only_ship.append(data.iloc[i])

# %%
only_vehicle
# Out:
# [File        1.tif
#  Vehicle        68
#  Airplane        0
#  Ship            0
#  Name: 1, dtype: object, File        8.tif
#  Vehicle       118
#  Airplane        0
#  Ship            0
#  Name: 8, dtype: object, File        18.tif
#  Vehicle         87
#  Airplane         0
#  Ship             0
#  Name: 18, dtype: object, File        21.tif
#  Vehicle         56
#  Airplane         0
#  Ship             0
#  Name: 21, dtype: object, File        22.tif
#  Vehicle         49
#  Airplane         0
#  Ship             0
#  Name: 22, dtype: object, File        23.tif
#  Vehicle        162
#  Airplane         0
#  Ship             0
#  Name: 23, dtype: object, File        24.tif
#  Vehicle         13
#  Airplane         0
#  Ship             0
#  Name: 24, dtype: object, File        25.tif
#  Vehicle         60
#  Airplane         0
#  Ship             0
#  Name: 25, dtype: object, File        26.tif
#  Vehicle        108
#  Airplane         0
#  Ship             0
#  Name: 26, dtype: object, File        27.tif
#  Vehicle          8
#  Airplane         0
#  Ship             0
#  Name: 27, dtype: object, File        29.tif
#  Vehicle         22
#  Airplane         0
#  Ship             0
#  Name: 29, dtype: object, File        31.tif
#  Vehicle         65
#  Airplane         0
#  Ship             0
#  Name: 31, dtype: object, File        37.tif
#  Vehicle          1
#  Airplane         0
#  Ship             0
#  Name: 37, dtype: object, File        39.tif
#  Vehicle         40
#  Airplane         0
#  Ship             0
#  Name: 39, dtype: object, File        47.tif
#  Vehicle         75
#  Airplane         0
#  Ship             0
#  Name: 47, dtype: object, File        50.tif
#  Vehicle         11
#  Airplane         0
#  Ship             0
#  Name: 50, dtype: object, File        57.tif
#  Vehicle         14
#  Airplane         0
#  Ship             0
#  Name: 57, dtype: object, File        58.tif
#  Vehicle         40
#  Airplane         0
#  Ship             0
#  Name: 58, dtype: object, File        59.tif
#  Vehicle        246
#  Airplane         0
#  Ship             0
#  Name: 59, dtype: object, File        60.tif
#  Vehicle         22
#  Airplane         0
#  Ship             0
#  Name: 60, dtype: object, File        64.tif
#  Vehicle         16
#  Airplane         0
#  Ship             0
#  Name: 64, dtype: object, File        66.tif
#  Vehicle         15
#  Airplane         0
#  Ship             0
#  Name: 66, dtype: object, File        68.tif
#  Vehicle        133
#  Airplane         0
#  Ship             0
#  Name: 68, dtype: object, File        69.tif
#  Vehicle         67
#  Airplane         0
#  Ship             0
#  Name: 69, dtype: object, File        71.tif
#  Vehicle         17
#  Airplane         0
#  Ship             0
#  Name: 71, dtype: object, File        72.tif
#  Vehicle        110
#  Airplane         0
#  Ship             0
#  Name: 72, dtype: object, File        74.tif
#  Vehicle        146
#  Airplane         0
#  Ship             0
#  Name: 74, dtype: object, File        76.tif
#  Vehicle         22
#  Airplane         0
#  Ship             0
#  Name: 76, dtype: object, File        77.tif
#  Vehicle         68
#  Airplane         0
#  Ship             0
#  Name: 77, dtype: object, File        83.tif
#  Vehicle        103
#  Airplane         0
#  Ship             0
#  Name: 83, dtype: object, File        84.tif
#  Vehicle        140
#  Airplane         0
#  Ship             0
#  Name: 84, dtype: object, File        85.tif
#  Vehicle         51
#  Airplane         0
#  Ship             0
#  Name: 85, dtype: object, File        87.tif
#  Vehicle         47
#  Airplane         0
#  Ship             0
#  Name: 87, dtype: object, File        88.tif
#  Vehicle         25
#  Airplane         0
#  Ship             0
#  Name: 88, dtype: object, File        92.tif
#  Vehicle         54
#  Airplane         0
#  Ship             0
#  Name: 92, dtype: object, File        93.tif
#  Vehicle         75
#  Airplane         0
#  Ship             0
#  Name: 93, dtype: object, File        97.tif
#  Vehicle         53
#  Airplane         0
#  Ship             0
#  Name: 97, dtype: object, File        99.tif
#  Vehicle         83
#  Airplane         0
#  Ship             0
#  Name: 99, dtype: object, File        100.tif
#  Vehicle          52
#  Airplane          0
#  Ship              0
#  Name: 100, dtype: object, File        102.tif
#  Vehicle          19
#  Airplane          0
#  Ship              0
#  Name: 102, dtype: object, File        103.tif
#  Vehicle          17
#  Airplane          0
#  Ship              0
#  Name: 103, dtype: object, File        105.tif
#  Vehicle         146
#  Airplane          0
#  Ship              0
#  Name: 105, dtype: object, File        110.tif
#  Vehicle          20
#  Airplane          0
#  Ship              0
#  Name: 110, dtype: object, File        111.tif
#  Vehicle         136
#  Airplane          0
#  Ship              0
#  Name: 111, dtype: object, File        112.tif
#  Vehicle         169
#  Airplane          0
#  Ship              0
#  Name: 112, dtype: object, File        115.tif
#  Vehicle          49
#  Airplane          0
#  Ship              0
#  Name: 115, dtype: object, File        117.tif
#  Vehicle         153
#  Airplane          0
#  Ship              0
#  Name: 117, dtype: object, File        118.tif
#  Vehicle         103
#  Airplane          0
#  Ship              0
#  Name: 118, dtype: object, File        119.tif
#  Vehicle         315
#  Airplane          0
#  Ship              0
#  Name: 119, dtype: object, File        121.tif
#  Vehicle         164
#  Airplane          0
#  Ship              0
#  Name: 121, dtype: object, File        125.tif
#  Vehicle          15
#  Airplane          0
#  Ship              0
#  Name: 125, dtype: object, File        127.tif
#  Vehicle          37
#  Airplane          0
#  Ship              0
#  Name: 127, dtype: object, File        132.tif
#  Vehicle          27
#  Airplane          0
#  Ship              0
#  Name: 132, dtype: object, File        140.tif
#  Vehicle          81
#  Airplane          0
#  Ship              0
#  Name: 140, dtype: object, File        143.tif
#  Vehicle          84
#  Airplane          0
#  Ship              0
#  Name: 143, dtype: object, File        144.tif
#  Vehicle          51
#  Airplane          0
#  Ship              0
#  Name: 144, dtype: object, File        145.tif
#  Vehicle         358
#  Airplane          0
#  Ship              0
#  Name: 145, dtype: object, File        147.tif
#  Vehicle         110
#  Airplane          0
#  Ship              0
#  Name: 147, dtype: object, File        149.tif
#  Vehicle           9
#  Airplane          0
#  Ship              0
#  Name: 149, dtype: object, File        150.tif
#  Vehicle          13
#  Airplane          0
#  Ship              0
#  Name: 150, dtype: object, File        153.tif
#  Vehicle          55
#  Airplane          0
#  Ship              0
#  Name: 153, dtype: object, File        155.tif
#  Vehicle          21
#  Airplane          0
#  Ship              0
#  Name: 155, dtype: object, File        159.tif
#  Vehicle          18
#  Airplane          0
#  Ship              0
#  Name: 159, dtype: object, File        161.tif
#  Vehicle         224
#  Airplane          0
#  Ship              0
#  Name: 161, dtype: object, File        165.tif
#  Vehicle          36
#  Airplane          0
#  Ship              0
#  Name: 165, dtype: object, File        166.tif
#  Vehicle          15
#  Airplane          0
#  Ship              0
#  Name: 166, dtype: object, File        168.tif
#  Vehicle           1
#  Airplane          0
#  Ship              0
#  Name: 168, dtype: object, File        169.tif
#  Vehicle          52
#  Airplane          0
#  Ship              0
#  Name: 169, dtype: object, File        171.tif
#  Vehicle         116
#  Airplane          0
#  Ship              0
#  Name: 171, dtype: object, File        172.tif
#  Vehicle         107
#  Airplane          0
#  Ship              0
#  Name: 172, dtype: object, File        174.tif
#  Vehicle         190
#  Airplane          0
#  Ship              0
#  Name: 174, dtype: object, File        179.tif
#  Vehicle          60
#  Airplane          0
#  Ship              0
#  Name: 179, dtype: object, File        181.tif
#  Vehicle          14
#  Airplane          0
#  Ship              0
#  Name: 181, dtype: object, File        185.tif
#  Vehicle         248
#  Airplane          0
#  Ship              0
#  Name: 185, dtype: object, File        186.tif
#  Vehicle          63
#  Airplane          0
#  Ship              0
#  Name: 186, dtype: object, File        188.tif
#  Vehicle          52
#  Airplane          0
#  Ship              0
#  Name: 188, dtype: object, File        190.tif
#  Vehicle          82
#  Airplane          0
#  Ship              0
#  Name: 190, dtype: object, File        192.tif
#  Vehicle          29
#  Airplane          0
#  Ship              0
#  Name: 192, dtype: object, File        197.tif
#  Vehicle         113
#  Airplane          0
#  Ship              0
#  Name: 197, dtype: object, File        199.tif
#  Vehicle         199
#  Airplane          0
#  Ship              0
#  Name: 199, dtype: object, File        200.tif
#  Vehicle         144
#  Airplane          0
#  Ship              0
#  Name: 200, dtype: object, File        204.tif
#  Vehicle          75
#  Airplane          0
#  Ship              0
#  Name: 204, dtype: object, File        208.tif
#  Vehicle         132
#  Airplane          0
#  Ship              0
#  Name: 208, dtype: object, File        209.tif
#  Vehicle          63
#  Airplane          0
#  Ship              0
#  Name: 209, dtype: object, File        211.tif
#  Vehicle         102
#  Airplane          0
#  Ship              0
#  Name: 211, dtype: object, File        213.tif
#  Vehicle          36
#  Airplane          0
#  Ship              0
#  Name: 213, dtype: object, File        215.tif
#  Vehicle          21
#  Airplane          0
#  Ship              0
#  Name: 215, dtype: object, File        216.tif
#  Vehicle         100
#  Airplane          0
#  Ship              0
#  Name: 216, dtype: object, File        217.tif
#  Vehicle          62
#  Airplane          0
#  Ship              0
#  Name: 217, dtype: object, File        220.tif
#  Vehicle          40
#  Airplane          0
#  Ship              0
#  Name: 220, dtype: object, File        225.tif
#  Vehicle          49
#  Airplane          0
#  Ship              0
#  Name: 225, dtype: object, File        226.tif
#  Vehicle          51
#  Airplane          0
#  Ship              0
#  Name: 226, dtype: object, File        231.tif
#  Vehicle         132
#  Airplane          0
#  Ship              0
#  Name: 231, dtype: object, File        232.tif
#  Vehicle          52
#  Airplane          0
#  Ship              0
#  Name: 232, dtype: object, File        237.tif
#  Vehicle          34
#  Airplane          0
#  Ship              0
#  Name: 237, dtype: object, File        238.tif
#  Vehicle         222
#  Airplane          0
#  Ship              0
#  Name: 238, dtype: object, File        240.tif
#  Vehicle          33
#  Airplane          0
#  Ship              0
#  Name: 240, dtype: object, File        241.tif
#  Vehicle          51
#  Airplane          0
#  Ship              0
#  Name: 241, dtype: object, File        242.tif
#  Vehicle          41
#  Airplane          0
#  Ship              0
#  Name: 242, dtype: object, File        244.tif
#  Vehicle         125
#  Airplane          0
#  Ship              0
#  Name: 244, dtype: object, File        249.tif
#  Vehicle          74
#  Airplane          0
#  Ship              0
#  Name: 249, dtype: object, File        252.tif
#  Vehicle         113
#  Airplane          0
#  Ship              0
#  Name: 252, dtype: object, File        253.tif
#  Vehicle          42
#  Airplane          0
#  Ship              0
#  Name: 253, dtype: object, File        257.tif
#  Vehicle           3
#  Airplane          0
#  Ship              0
#  Name: 257, dtype: object, File        258.tif
#  Vehicle          97
#  Airplane          0
#  Ship              0
#  Name: 258, dtype: object, File        262.tif
#  Vehicle         122
#  Airplane          0
#  Ship              0
#  Name: 262, dtype: object, File        264.tif
#  Vehicle          29
#  Airplane          0
#  Ship              0
#  Name: 264, dtype: object, File        266.tif
#  Vehicle           3
#  Airplane          0
#  Ship              0
#  Name: 266, dtype: object, File        269.tif
#  Vehicle         136
#  Airplane          0
#  Ship              0
#  Name: 269, dtype: object, File        275.tif
#  Vehicle          55
#  Airplane          0
#  Ship              0
#  Name: 275, dtype: object, File        280.tif
#  Vehicle          22
#  Airplane          0
#  Ship              0
#  Name: 280, dtype: object, File        283.tif
#  Vehicle          35
#  Airplane          0
#  Ship              0
#  Name: 283, dtype: object, File        285.tif
#  Vehicle         127
#  Airplane          0
#  Ship              0
#  Name: 285, dtype: object, File        286.tif
#  Vehicle          38
#  Airplane          0
#  Ship              0
#  Name: 286, dtype: object, File        287.tif
#  Vehicle          14
#  Airplane          0
#  Ship              0
#  Name: 287, dtype: object, File        289.tif
#  Vehicle         136
#  Airplane          0
#  Ship              0
#  Name: 289, dtype: object, File        290.tif
#  Vehicle          73
#  Airplane          0
#  Ship              0
#  Name: 290, dtype: object, File        291.tif
#  Vehicle         130
#  Airplane          0
#  Ship              0
#  Name: 291, dtype: object, File        294.tif
#  Vehicle          26
#  Airplane          0
#  Ship              0
#  Name: 294, dtype: object, File        296.tif
#  Vehicle         106
#  Airplane          0
#  Ship              0
#  Name: 296, dtype: object, File        298.tif
#  Vehicle          72
#  Airplane          0
#  Ship              0
#  Name: 298, dtype: object, File        299.tif
#  Vehicle           3
#  Airplane          0
#  Ship              0
#  Name: 299, dtype: object, File        301.tif
#  Vehicle         241
#  Airplane          0
#  Ship              0
#  Name: 301, dtype: object, File        302.tif
#  Vehicle         155
#  Airplane          0
#  Ship              0
#  Name: 302, dtype: object, File        307.tif
#  Vehicle          25
#  Airplane          0
#  Ship              0
#  Name: 307, dtype: object, File        309.tif
#  Vehicle          90
#  Airplane          0
#  Ship              0
#  Name: 309, dtype: object, File        311.tif
#  Vehicle         144
#  Airplane          0
#  Ship              0
#  Name: 311, dtype: object, File        313.tif
#  Vehicle         124
#  Airplane          0
#  Ship              0
#  Name: 313, dtype: object, File        320.tif
#  Vehicle           9
#  Airplane          0
#  Ship              0
#  Name: 320, dtype: object, File        323.tif
#  Vehicle          80
#  Airplane          0
#  Ship              0
#  Name: 323, dtype: object, File        325.tif
#  Vehicle         124
#  Airplane          0
#  Ship              0
#  Name: 325, dtype: object, File        328.tif
#  Vehicle         104
#  Airplane          0
#  Ship              0
#  Name: 328, dtype: object, File        329.tif
#  Vehicle         188
#  Airplane          0
#  Ship              0
#  Name: 329, dtype: object, File        330.tif
#  Vehicle          33
#  Airplane          0
#  Ship              0
#  Name: 330, dtype: object, File        331.tif
#  Vehicle         119
#  Airplane          0
#  Ship              0
#  Name: 331, dtype: object, File        332.tif
#  Vehicle           3
#  Airplane          0
#  Ship              0
#  Name: 332, dtype: object, File        334.tif
#  Vehicle         156
#  Airplane          0
#  Ship              0
#  Name: 334, dtype: object, File        341.tif
#  Vehicle          35
#  Airplane          0
#  Ship              0
#  Name: 341, dtype: object, File        342.tif
#  Vehicle          63
#  Airplane          0
#  Ship              0
#  Name: 342, dtype: object, File        343.tif
#  Vehicle          35
#  Airplane          0
#  Ship              0
#  Name: 343, dtype: object, File        344.tif
#  Vehicle         248
#  Airplane          0
#  Ship              0
#  Name: 344, dtype: object, File        345.tif
#  Vehicle         101
#  Airplane          0
#  Ship              0
#  Name: 345, dtype: object, File        346.tif
#  Vehicle         141
#  Airplane          0
#  Ship              0
#  Name: 346, dtype: object, File        347.tif
#  Vehicle          48
#  Airplane          0
#  Ship              0
#  Name: 347, dtype: object, File        350.tif
#  Vehicle         120
#  Airplane          0
#  Ship              0
#  Name: 350, dtype: object, File        352.tif
#  Vehicle           7
#  Airplane          0
#  Ship              0
#  Name: 352, dtype: object, File        353.tif
#  Vehicle          69
#  Airplane          0
#  Ship              0
#  Name: 353, dtype: object, File        355.tif
#  Vehicle          15
#  Airplane          0
#  Ship              0
#  Name: 355, dtype: object, File        356.tif
#  Vehicle          45
#  Airplane          0
#  Ship              0
#  Name: 356, dtype: object, File        357.tif
#  Vehicle           3
#  Airplane          0
#  Ship              0
#  Name: 357, dtype: object, File        359.tif
#  Vehicle          51
#  Airplane          0
#  Ship              0
#  Name: 359, dtype: object, File        361.tif
#  Vehicle          94
#  Airplane          0
#  Ship              0
#  Name: 361, dtype: object, File        362.tif
#  Vehicle          98
#  Airplane          0
#  Ship              0
#  Name: 362, dtype: object, File        363.tif
#  Vehicle         150
#  Airplane          0
#  Ship              0
#  Name: 363, dtype: object, File        368.tif
#  Vehicle          13
#  Airplane          0
#  Ship              0
#  Name: 368, dtype: object, File        369.tif
#  Vehicle          85
#  Airplane          0
#  Ship              0
#  Name: 369, dtype: object, File        371.tif
#  Vehicle           8
#  Airplane          0
#  Ship              0
#  Name: 371, dtype: object, File        376.tif
#  Vehicle          41
#  Airplane          0
#  Ship              0
#  Name: 376, dtype: object, File        377.tif
#  Vehicle          18
#  Airplane          0
#  Ship              0
#  Name: 377, dtype: object, File        381.tif
#  Vehicle          72
#  Airplane          0
#  Ship              0
#  Name: 381, dtype: object, File        384.tif
#  Vehicle          46
#  Airplane          0
#  Ship              0
#  Name: 384, dtype: object, File        385.tif
#  Vehicle          79
#  Airplane          0
#  Ship              0
#  Name: 385, dtype: object, File        387.tif
#  Vehicle          40
#  Airplane          0
#  Ship              0
#  Name: 387, dtype: object, File        389.tif
#  Vehicle         123
#  Airplane          0
#  Ship              0
#  Name: 389, dtype: object, File        390.tif
#  Vehicle          29
#  Airplane          0
#  Ship              0
#  Name: 390, dtype: object, File        391.tif
#  Vehicle          31
#  Airplane          0
#  Ship              0
#  Name: 391, dtype: object, File        392.tif
#  Vehicle           4
#  Airplane          0
#  Ship              0
#  Name: 392, dtype: object, File        393.tif
#  Vehicle         116
#  Airplane          0
#  Ship              0
#  Name: 393, dtype: object, File        397.tif
#  Vehicle          39
#  Airplane          0
#  Ship              0
#  Name: 397, dtype: object, File        398.tif
#  Vehicle         164
#  Airplane          0
#  Ship              0
#  Name: 398, dtype: object, File        399.tif
#  Vehicle          76
#  Airplane          0
#  Ship              0
#  Name: 399, dtype: object, File        402.tif
#  Vehicle           1
#  Airplane          0
#  Ship              0
#  Name: 402, dtype: object, File        403.tif
#  Vehicle          51
#  Airplane          0
#  Ship              0
#  Name: 403, dtype: object, File        408.tif
#  Vehicle         102
#  Airplane          0
#  Ship              0
#  Name: 408, dtype: object, File        410.tif
#  Vehicle         127
#  Airplane          0
#  Ship              0
#  Name: 410, dtype: object, File        411.tif
#  Vehicle          58
#  Airplane          0
#  Ship              0
#  Name: 411, dtype: object, File        412.tif
#  Vehicle          24
#  Airplane          0
#  Ship              0
#  Name: 412, dtype: object, File        413.tif
#  Vehicle         155
#  Airplane          0
#  Ship              0
#  Name: 413, dtype: object, File        415.tif
#  Vehicle         134
#  Airplane          0
#  Ship              0
#  Name: 415, dtype: object, File        416.tif
#  Vehicle         184
#  Airplane          0
#  Ship              0
#  Name: 416, dtype: object, File        417.tif
#  Vehicle         129
#  Airplane          0
#  Ship              0
#  Name: 417, dtype: object, File        419.tif
#  Vehicle         177
#  Airplane          0
#  Ship              0
#  Name: 419, dtype: object, File        423.tif
#  Vehicle          28
#  Airplane          0
#  Ship              0
#  Name: 423, dtype: object, File        428.tif
#  Vehicle          94
#  Airplane          0
#  Ship              0
#  Name: 428, dtype: object, File        429.tif
#  Vehicle         110
#  Airplane          0
#  Ship              0
#  Name: 429, dtype: object, File        433.tif
#  Vehicle         111
#  Airplane          0
#  Ship              0
#  Name: 433, dtype: object, File        437.tif
#  Vehicle          62
#  Airplane          0
#  Ship              0
#  Name: 437, dtype: object, File        439.tif
#  Vehicle          33
#  Airplane          0
#  Ship              0
#  Name: 439, dtype: object, File        447.tif
#  Vehicle           3
#  Airplane          0
#  Ship              0
#  Name: 447, dtype: object, File        448.tif
#  Vehicle          51
#  Airplane          0
#  Ship              0
#  Name: 448, dtype: object, File        449.tif
#  Vehicle         161
#  Airplane          0
#  Ship              0
#  Name: 449, dtype: object, File        451.tif
#  Vehicle          93
#  Airplane          0
#  Ship              0
#  Name: 451, dtype: object, File        452.tif
#  Vehicle         136
#  Airplane          0
#  Ship              0
#  Name: 452, dtype: object, File        454.tif
#  Vehicle          16
#  Airplane          0
#  Ship              0
#  Name: 454, dtype: object, File        460.tif
#  Vehicle          84
#  Airplane          0
#  Ship              0
#  Name: 460, dtype: object, File        461.tif
#  Vehicle          24
#  Airplane          0
#  Ship              0
#  Name: 461, dtype: object, File        463.tif
#  Vehicle           2
#  Airplane          0
#  Ship              0
#  Name: 463, dtype: object, File        464.tif
#  Vehicle           9
#  Airplane          0
#  Ship              0
#  Name: 464, dtype: object, File        465.tif
#  Vehicle          30
#  Airplane          0
#  Ship              0
#  Name: 465, dtype: object, File        473.tif
#  Vehicle          41
#  Airplane          0
#  Ship              0
#  Name: 473, dtype: object, File        487.tif
#  Vehicle         137
#  Airplane          0
#  Ship              0
#  Name: 487, dtype: object, File        490.tif
#  Vehicle         165
#  Airplane          0
#  Ship              0
#  Name: 490, dtype: object, File        491.tif
#  Vehicle          20
#  Airplane          0
#  Ship              0
#  Name: 491, dtype: object, File        492.tif
#  Vehicle           9
#  Airplane          0
#  Ship              0
#  Name: 492, dtype: object, File        494.tif
#  Vehicle          19
#  Airplane          0
#  Ship              0
#  Name: 494, dtype: object, File        495.tif
#  Vehicle          36
#  Airplane          0
#  Ship              0
#  Name: 495, dtype: object, File        496.tif
#  Vehicle         164
#  Airplane          0
#  Ship              0
#  Name: 496, dtype: object, File        499.tif
#  Vehicle         267
#  Airplane          0
#  Ship              0
#  Name: 499, dtype: object, File        501.tif
#  Vehicle         189
#  Airplane          0
#  Ship              0
#  Name: 501, dtype: object, File        502.tif
#  Vehicle          43
#  Airplane          0
#  Ship              0
#  Name: 502, dtype: object, File        503.tif
#  Vehicle         107
#  Airplane          0
#  Ship              0
#  Name: 503, dtype: object, File        507.tif
#  Vehicle          70
#  Airplane          0
#  Ship              0
#  Name: 507, dtype: object, File        508.tif
#  Vehicle          93
#  Airplane          0
#  Ship              0
#  Name: 508, dtype: object, File        509.tif
#  Vehicle          76
#  Airplane          0
#  Ship              0
#  Name: 509, dtype: object, File        511.tif
#  Vehicle         112
#  Airplane          0
#  Ship              0
#  Name: 511, dtype: object, File        512.tif
#  Vehicle          53
#  Airplane          0
#  Ship              0
#  Name: 512, dtype: object, File        516.tif
#  Vehicle          50
#  Airplane          0
#  Ship              0
#  Name: 516, dtype: object, File        519.tif
#  Vehicle          10
#  Airplane          0
#  Ship              0
#  Name: 519, dtype: object, File        529.tif
#  Vehicle          81
#  Airplane          0
#  Ship              0
#  Name: 529, dtype: object, File        530.tif
#  Vehicle          36
#  Airplane          0
#  Ship              0
#  Name: 530, dtype: object, File        539.tif
#  Vehicle          22
#  Airplane          0
#  Ship              0
#  Name: 539, dtype: object, File        545.tif
#  Vehicle          64
#  Airplane          0
#  Ship              0
#  Name: 545, dtype: object, File        548.tif
#  Vehicle          22
#  Airplane          0
#  Ship              0
#  Name: 548, dtype: object, File        550.tif
#  Vehicle          27
#  Airplane          0
#  Ship              0
#  Name: 550, dtype: object, File        553.tif
#  Vehicle         222
#  Airplane          0
#  Ship              0
#  Name: 553, dtype: object, File        555.tif
#  Vehicle          44
#  Airplane          0
#  Ship              0
#  Name: 555, dtype: object, File        556.tif
#  Vehicle          45
#  Airplane          0
#  Ship              0
#  Name: 556, dtype: object, File        557.tif
#  Vehicle         173
#  Airplane          0
#  Ship              0
#  Name: 557, dtype: object, File        558.tif
#  Vehicle          65
#  Airplane          0
#  Ship              0
#  Name: 558, dtype: object, File        559.tif
#  Vehicle           9
#  Airplane          0
#  Ship              0
#  Name: 559, dtype: object, File        560.tif
#  Vehicle           3
#  Airplane          0
#  Ship              0
#  Name: 560, dtype: object, File        561.tif
#  Vehicle          15
#  Airplane          0
#  Ship              0
#  Name: 561, dtype: object, File        562.tif
#  Vehicle         108
#  Airplane          0
#  Ship              0
#  Name: 562, dtype: object, File        565.tif
#  Vehicle          30
#  Airplane          0
#  Ship              0
#  Name: 565, dtype: object, File        567.tif
#  Vehicle          14
#  Airplane          0
#  Ship              0
#  Name: 567, dtype: object, File        568.tif
#  Vehicle         142
#  Airplane          0
#  Ship              0
#  Name: 568, dtype: object, File        569.tif
#  Vehicle          10
#  Airplane          0
#  Ship              0
#  Name: 569, dtype: object, File        570.tif
#  Vehicle         111
#  Airplane          0
#  Ship              0
#  Name: 570, dtype: object, File        571.tif
#  Vehicle         264
#  Airplane          0
#  Ship              0
#  Name: 571, dtype: object, File        573.tif
#  Vehicle         118
#  Airplane          0
#  Ship              0
#  Name: 573, dtype: object, File        574.tif
#  Vehicle         455
#  Airplane          0
#  Ship              0
#  Name: 574, dtype: object, File        575.tif
#  Vehicle         130
#  Airplane          0
#  Ship              0
#  Name: 575, dtype: object, File        577.tif
#  Vehicle         123
#  Airplane          0
#  Ship              0
#  Name: 577, dtype: object, File        580.tif
#  Vehicle         162
#  Airplane          0
#  Ship              0
#  Name: 580, dtype: object, File        581.tif
#  Vehicle         150
#  Airplane          0
#  Ship              0
#  Name: 581, dtype: object, File        584.tif
#  Vehicle          46
#  Airplane          0
#  Ship              0
#  Name: 584, dtype: object, File        586.tif
#  Vehicle         135
#  Airplane          0
#  Ship              0
#  Name: 586, dtype: object, File        589.tif
#  Vehicle         104
#  Airplane          0
#  Ship              0
#  Name: 589, dtype: object, File        590.tif
#  Vehicle         128
#  Airplane          0
#  Ship              0
#  Name: 590, dtype: object, File        591.tif
#  Vehicle         208
#  Airplane          0
#  Ship              0
#  Name: 591, dtype: object, File        594.tif
#  Vehicle         179
#  Airplane          0
#  Ship              0
#  Name: 594, dtype: object, File        595.tif
#  Vehicle          39
#  Airplane          0
#  Ship              0
#  Name: 595, dtype: object, File        596.tif
#  Vehicle         179
#  Airplane          0
#  Ship              0
#  Name: 596, dtype: object, File        598.tif
#  Vehicle         147
#  Airplane          0
#  Ship              0
#  Name: 598, dtype: object, File        600.tif
#  Vehicle           2
#  Airplane          0
#  Ship              0
#  Name: 600, dtype: object, File        602.tif
#  Vehicle           4
#  Airplane          0
#  Ship              0
#  Name: 602, dtype: object, File        603.tif
#  Vehicle         106
#  Airplane          0
#  Ship              0
#  Name: 603, dtype: object, File        604.tif
#  Vehicle          71
#  Airplane          0
#  Ship              0
#  Name: 604, dtype: object, File        608.tif
#  Vehicle         147
#  Airplane          0
#  Ship              0
#  Name: 608, dtype: object, File        609.tif
#  Vehicle          53
#  Airplane          0
#  Ship              0
#  Name: 609, dtype: object, File        611.tif
#  Vehicle          74
#  Airplane          0
#  Ship              0
#  Name: 611, dtype: object, File        612.tif
#  Vehicle          23
#  Airplane          0
#  Ship              0
#  Name: 612, dtype: object, File        616.tif
#  Vehicle           1
#  Airplane          0
#  Ship              0
#  Name: 616, dtype: object, File        618.tif
#  Vehicle          35
#  Airplane          0
#  Ship              0
#  Name: 618, dtype: object, File        620.tif
#  Vehicle        1075
#  Airplane          0
#  Ship              0
#  Name: 620, dtype: object, File        621.tif
#  Vehicle          47
#  Airplane          0
#  Ship              0
#  Name: 621, dtype: object, File        623.tif
#  Vehicle         115
#  Airplane          0
#  Ship              0
#  Name: 623, dtype: object, File        624.tif
#  Vehicle           7
#  Airplane          0
#  Ship              0
#  Name: 624, dtype: object, File        627.tif
#  Vehicle         156
#  Airplane          0
#  Ship              0
#  Name: 627, dtype: object, File        628.tif
#  Vehicle          46
#  Airplane          0
#  Ship              0
#  Name: 628, dtype: object, File        629.tif
#  Vehicle         177
#  Airplane          0
#  Ship              0
#  Name: 629, dtype: object, File        630.tif
#  Vehicle          80
#  Airplane          0
#  Ship              0
#  Name: 630, dtype: object, File        631.tif
#  Vehicle          69
#  Airplane          0
#  Ship              0
#  Name: 631, dtype: object, File        632.tif
#  Vehicle          42
#  Airplane          0
#  Ship              0
#  Name: 632, dtype: object, File        635.tif
#  Vehicle         174
#  Airplane          0
#  Ship              0
#  Name: 635, dtype: object, File        636.tif
#  Vehicle         102
#  Airplane          0
#  Ship              0
#  Name: 636, dtype: object, File        638.tif
#  Vehicle          22
#  Airplane          0
#  Ship              0
#  Name: 638, dtype: object, File        642.tif
#  Vehicle         162
#  Airplane          0
#  Ship              0
#  Name: 642, dtype: object, File        646.tif
#  Vehicle           1
#  Airplane          0
#  Ship              0
#  Name: 646, dtype: object, File        653.tif
#  Vehicle          60
#  Airplane          0
#  Ship              0
#  Name: 653, dtype: object, File        656.tif
#  Vehicle          50
#  Airplane          0
#  Ship              0
#  Name: 656, dtype: object, File        658.tif
#  Vehicle         121
#  Airplane          0
#  Ship              0
#  Name: 658, dtype: object, File        659.tif
#  Vehicle          62
#  Airplane          0
#  Ship              0
#  Name: 659, dtype: object, File        661.tif
#  Vehicle          19
#  Airplane          0
#  Ship              0
#  Name: 661, dtype: object, File        663.tif
#  Vehicle         138
#  Airplane          0
#  Ship              0
#  Name: 663, dtype: object, File        665.tif
#  Vehicle         139
#  Airplane          0
#  Ship              0
#  Name: 665, dtype: object, File        667.tif
#  Vehicle          54
#  Airplane          0
#  Ship              0
#  Name: 667, dtype: object, File        669.tif
#  Vehicle          35
#  Airplane          0
#  Ship              0
#  Name: 669, dtype: object, File        670.tif
#  Vehicle          19
#  Airplane          0
#  Ship              0
#  Name: 670, dtype: object, File        676.tif
#  Vehicle           9
#  Airplane          0
#  Ship              0
#  Name: 676, dtype: object, File        678.tif
#  Vehicle         185
#  Airplane          0
#  Ship              0
#  Name: 678, dtype: object, File        681.tif
#  Vehicle         260
#  Airplane          0
#  Ship              0
#  Name: 681, dtype: object, File        683.tif
#  Vehicle          15
#  Airplane          0
#  Ship              0
#  Name: 683, dtype: object, File        687.tif
#  Vehicle         141
#  Airplane          0
#  Ship              0
#  Name: 687, dtype: object, File        689.tif
#  Vehicle         151
#  Airplane          0
#  Ship              0
#  Name: 689, dtype: object, File        692.tif
#  Vehicle          69
#  Airplane          0
#  Ship              0
#  Name: 692, dtype: object, File        694.tif
#  Vehicle          37
#  Airplane          0
#  Ship              0
#  Name: 694, dtype: object, File        696.tif
#  Vehicle         125
#  Airplane          0
#  Ship              0
#  Name: 696, dtype: object, File        698.tif
#  Vehicle          13
#  Airplane          0
#  Ship              0
#  Name: 698, dtype: object, File        700.tif
#  Vehicle         170
#  Airplane          0
#  Ship              0
#  Name: 700, dtype: object, File        702.tif
#  Vehicle         148
#  Airplane          0
#  Ship              0
#  Name: 702, dtype: object, File        705.tif
#  Vehicle          61
#  Airplane          0
#  Ship              0
#  Name: 705, dtype: object, File        706.tif
#  Vehicle          49
#  Airplane          0
#  Ship              0
#  Name: 706, dtype: object, File        709.tif
#  Vehicle         156
#  Airplane          0
#  Ship              0
#  Name: 709, dtype: object, File        710.tif
#  Vehicle         137
#  Airplane          0
#  Ship              0
#  Name: 710, dtype: object, File        711.tif
#  Vehicle          37
#  Airplane          0
#  Ship              0
#  Name: 711, dtype: object, File        712.tif
#  Vehicle          30
#  Airplane          0
#  Ship              0
#  Name: 712, dtype: object, File        713.tif
#  Vehicle          17
#  Airplane          0
#  Ship              0
#  Name: 713, dtype: object, File        714.tif
#  Vehicle          61
#  Airplane          0
#  Ship              0
#  Name: 714, dtype: object, File        715.tif
#  Vehicle          29
#  Airplane          0
#  Ship              0
#  Name: 715, dtype: object, File        717.tif
#  Vehicle          29
#  Airplane          0
#  Ship              0
#  Name: 717, dtype: object, File        719.tif
#  Vehicle           2
#  Airplane          0
#  Ship              0
#  Name: 719, dtype: object, File        721.tif
#  Vehicle          66
#  Airplane          0
#  Ship              0
#  Name: 721, dtype: object, File        722.tif
#  Vehicle          67
#  Airplane          0
#  Ship              0
#  Name: 722, dtype: object, File        723.tif
#  Vehicle           2
#  Airplane          0
#  Ship              0
#  Name: 723, dtype: object, File        725.tif
#  Vehicle          45
#  Airplane          0
#  Ship              0
#  Name: 725, dtype: object, File        726.tif
#  Vehicle         103
#  Airplane          0
#  Ship              0
#  Name: 726, dtype: object, File        730.tif
#  Vehicle          72
#  Airplane          0
#  Ship              0
#  Name: 730, dtype: object, File        731.tif
#  Vehicle          43
#  Airplane          0
#  Ship              0
#  Name: 731, dtype: object, File        734.tif
#  Vehicle         198
#  Airplane          0
#  Ship              0
#  Name: 734, dtype: object, File        735.tif
#  Vehicle          29
#  Airplane          0
#  Ship              0
#  Name: 735, dtype: object, File        736.tif
#  Vehicle          49
#  Airplane          0
#  Ship              0
#  Name: 736, dtype: object, File        737.tif
#  Vehicle          29
#  Airplane          0
#  Ship              0
#  Name: 737, dtype: object, File        738.tif
#  Vehicle         168
#  Airplane          0
#  Ship              0
#  Name: 738, dtype: object, File        740.tif
#  Vehicle          78
#  Airplane          0
#  Ship              0
#  Name: 740, dtype: object, File        742.tif
#  Vehicle         178
#  Airplane          0
#  Ship              0
#  Name: 742, dtype: object, File        743.tif
#  Vehicle           4
#  Airplane          0
#  Ship              0
#  Name: 743, dtype: object, File        749.tif
#  Vehicle          93
#  Airplane          0
#  Ship              0
#  Name: 749, dtype: object, File        750.tif
#  Vehicle         188
#  Airplane          0
#  Ship              0
#  Name: 750, dtype: object, File        751.tif
#  Vehicle           3
#  Airplane          0
#  Ship              0
#  Name: 751, dtype: object, File        752.tif
#  Vehicle         208
#  Airplane          0
#  Ship              0
#  Name: 752, dtype: object, File        756.tif
#  Vehicle         113
#  Airplane          0
#  Ship              0
#  Name: 756, dtype: object, File        757.tif
#  Vehicle         196
#  Airplane          0
#  Ship              0
#  Name: 757, dtype: object, File        759.tif
#  Vehicle         122
#  Airplane          0
#  Ship              0
#  Name: 759, dtype: object, File        763.tif
#  Vehicle          19
#  Airplane          0
#  Ship              0
#  Name: 763, dtype: object, File        765.tif
#  Vehicle          32
#  Airplane          0
#  Ship              0
#  Name: 765, dtype: object, File        768.tif
#  Vehicle          52
#  Airplane          0
#  Ship              0
#  Name: 768, dtype: object, File        769.tif
#  Vehicle         127
#  Airplane          0
#  Ship              0
#  Name: 769, dtype: object, File        770.tif
#  Vehicle          88
#  Airplane          0
#  Ship              0
#  Name: 770, dtype: object, File        773.tif
#  Vehicle           8
#  Airplane          0
#  Ship              0
#  Name: 773, dtype: object, File        775.tif
#  Vehicle           1
#  Airplane          0
#  Ship              0
#  Name: 775, dtype: object, File        776.tif
#  Vehicle          33
#  Airplane          0
#  Ship              0
#  Name: 776, dtype: object, File        779.tif
#  Vehicle          11
#  Airplane          0
#  Ship              0
#  Name: 779, dtype: object, File        781.tif
#  Vehicle          25
#  Airplane          0
#  Ship              0
#  Name: 781, dtype: object, File        783.tif
#  Vehicle          70
#  Airplane          0
#  Ship              0
#  Name: 783, dtype: object, File        787.tif
#  Vehicle         192
#  Airplane          0
#  Ship              0
#  Name: 787, dtype: object, File        788.tif
#  Vehicle          37
#  Airplane          0
#  Ship              0
#  Name: 788, dtype: object, File        792.tif
#  Vehicle          24
#  Airplane          0
#  Ship              0
#  Name: 792, dtype: object, File        795.tif
#  Vehicle          71
#  Airplane          0
#  Ship              0
#  Name: 795, dtype: object, File        797.tif
#  Vehicle          12
#  Airplane          0
#  Ship              0
#  Name: 797, dtype: object, File        800.tif
#  Vehicle         124
#  Airplane          0
#  Ship              0
#  Name: 800, dtype: object, File        801.tif
#  Vehicle           3
#  Airplane          0
#  Ship              0
#  Name: 801, dtype: object, File        802.tif
#  Vehicle         167
#  Airplane          0
#  Ship              0
#  Name: 802, dtype: object, File        805.tif
#  Vehicle          19
#  Airplane          0
#  Ship              0
#  Name: 805, dtype: object, File        811.tif
#  Vehicle          24
#  Airplane          0
#  Ship              0
#  Name: 811, dtype: object, File        815.tif
#  Vehicle          59
#  Airplane          0
#  Ship              0
#  Name: 815, dtype: object, File        817.tif
#  Vehicle         107
#  Airplane          0
#  Ship              0
#  Name: 817, dtype: object, File        818.tif
#  Vehicle          31
#  Airplane          0
#  Ship              0
#  Name: 818, dtype: object, File        825.tif
#  Vehicle          22
#  Airplane          0
#  Ship              0
#  Name: 825, dtype: object, File        826.tif
#  Vehicle          49
#  Airplane          0
#  Ship              0
#  Name: 826, dtype: object, File        828.tif
#  Vehicle          53
#  Airplane          0
#  Ship              0
#  Name: 828, dtype: object, File        830.tif
#  Vehicle          58
#  Airplane          0
#  Ship              0
#  Name: 830, dtype: object, File        831.tif
#  Vehicle           2
#  Airplane          0
#  Ship              0
#  Name: 831, dtype: object, File        836.tif
#  Vehicle         175
#  Airplane          0
#  Ship              0
#  Name: 836, dtype: object, File        838.tif
#  Vehicle          38
#  Airplane          0
#  Ship              0
#  Name: 838, dtype: object, File        840.tif
#  Vehicle         110
#  Airplane          0
#  Ship              0
#  Name: 840, dtype: object, File        842.tif
#  Vehicle          10
#  Airplane          0
#  Ship              0
#  Name: 842, dtype: object, File        845.tif
#  Vehicle          25
#  Airplane          0
#  Ship              0
#  Name: 845, dtype: object, File        846.tif
#  Vehicle          19
#  Airplane          0
#  Ship              0
#  Name: 846, dtype: object, File        847.tif
#  Vehicle          26
#  Airplane          0
#  Ship              0
#  Name: 847, dtype: object, File        849.tif
#  Vehicle          67
#  Airplane          0
#  Ship              0
#  Name: 849, dtype: object, File        852.tif
#  Vehicle         140
#  Airplane          0
#  Ship              0
#  Name: 852, dtype: object, File        853.tif
#  Vehicle         194
#  Airplane          0
#  Ship              0
#  Name: 853, dtype: object, File        854.tif
#  Vehicle          80
#  Airplane          0
#  Ship              0
#  Name: 854, dtype: object, File        856.tif
#  Vehicle          51
#  Airplane          0
#  Ship              0
#  Name: 856, dtype: object, File        862.tif
#  Vehicle         126
#  Airplane          0
#  Ship              0
#  Name: 862, dtype: object, File        863.tif
#  Vehicle           3
#  Airplane          0
#  Ship              0
#  Name: 863, dtype: object, File        864.tif
#  Vehicle          62
#  Airplane          0
#  Ship              0
#  Name: 864, dtype: object, File        865.tif
#  Vehicle          32
#  Airplane          0
#  Ship              0
#  Name: 865, dtype: object, File        866.tif
#  Vehicle          27
#  Airplane          0
#  Ship              0
#  Name: 866, dtype: object, File        869.tif
#  Vehicle         160
#  Airplane          0
#  Ship              0
#  Name: 869, dtype: object, File        870.tif
#  Vehicle         171
#  Airplane          0
#  Ship              0
#  Name: 870, dtype: object, File        872.tif
#  Vehicle         161
#  Airplane          0
#  Ship              0
#  Name: 872, dtype: object, File        874.tif
#  Vehicle           1
#  Airplane          0
#  Ship              0
#  Name: 874, dtype: object, File        875.tif
#  Vehicle         123
#  Airplane          0
#  Ship              0
#  Name: 875, dtype: object, File        877.tif
#  Vehicle         134
#  Airplane          0
#  Ship              0
#  Name: 877, dtype: object, File        878.tif
#  Vehicle           7
#  Airplane          0
#  Ship              0
#  Name: 878, dtype: object, File        882.tif
#  Vehicle          55
#  Airplane          0
#  Ship              0
#  Name: 882, dtype: object, File        883.tif
#  Vehicle           5
#  Airplane          0
#  Ship              0
#  Name: 883, dtype: object, File        885.tif
#  Vehicle          19
#  Airplane          0
#  Ship              0
#  Name: 885, dtype: object, File        886.tif
#  Vehicle          21
#  Airplane          0
#  Ship              0
#  Name: 886, dtype: object, File        887.tif
#  Vehicle         106
#  Airplane          0
#  Ship              0
#  Name: 887, dtype: object, File        888.tif
#  Vehicle         209
#  Airplane          0
#  Ship              0
#  Name: 888, dtype: object, File        890.tif
#  Vehicle           8
#  Airplane          0
#  Ship              0
#  Name: 890, dtype: object, File        894.tif
#  Vehicle          98
#  Airplane          0
#  Ship              0
#  Name: 894, dtype: object, File        895.tif
#  Vehicle          22
#  Airplane          0
#  Ship              0
#  Name: 895, dtype: object, File        897.tif
#  Vehicle          56
#  Airplane          0
#  Ship              0
#  Name: 897, dtype: object, File        898.tif
#  Vehicle          18
#  Airplane          0
#  Ship              0
#  Name: 898, dtype: object, File        899.tif
#  Vehicle          38
#  Airplane          0
#  Ship              0
#  Name: 899, dtype: object, File        901.tif
#  Vehicle          54
#  Airplane          0
#  Ship              0
#  Name: 901, dtype: object, File        904.tif
#  Vehicle         122
#  Airplane          0
#  Ship              0
#  Name: 904, dtype: object, File        906.tif
#  Vehicle          13
#  Airplane          0
#  Ship              0
#  Name: 906, dtype: object, File        909.tif
#  Vehicle          88
#  Airplane          0
#  Ship              0
#  Name: 909, dtype: object, File        912.tif
#  Vehicle           2
#  Airplane          0
#  Ship              0
#  Name: 912, dtype: object, File        914.tif
#  Vehicle          45
#  Airplane          0
#  Ship              0
#  Name: 914, dtype: object, File        916.tif
#  Vehicle          70
#  Airplane          0
#  Ship              0
#  Name: 916, dtype: object, File        917.tif
#  Vehicle          17
#  Airplane          0
#  Ship              0
#  Name: 917, dtype: object, File        918.tif
#  Vehicle           9
#  Airplane          0
#  Ship              0
#  Name: 918, dtype: object, File        919.tif
#  Vehicle         100
#  Airplane          0
#  Ship              0
#  Name: 919, dtype: object, File        920.tif
#  Vehicle          32
#  Airplane          0
#  Ship              0
#  Name: 920, dtype: object, File        922.tif
#  Vehicle          73
#  Airplane          0
#  Ship              0
#  Name: 922, dtype: object, File        926.tif
#  Vehicle          26
#  Airplane          0
#  Ship              0
#  Name: 926, dtype: object, File        928.tif
#  Vehicle         175
#  Airplane          0
#  Ship              0
#  Name: 928, dtype: object, File        929.tif
#  Vehicle         153
#  Airplane          0
#  Ship              0
#  Name: 929, dtype: object, File        931.tif
#  Vehicle          32
#  Airplane          0
#  Ship              0
#  Name: 931, dtype: object, File        932.tif
#  Vehicle         189
#  Airplane          0
#  Ship              0
#  Name: 932, dtype: object, File        933.tif
#  Vehicle          60
#  Airplane          0
#  Ship              0
#  Name: 933, dtype: object, File        934.tif
#  Vehicle          12
#  Airplane          0
#  Ship              0
#  Name: 934, dtype: object, File        936.tif
#  Vehicle          14
#  Airplane          0
#  Ship              0
#  Name: 936, dtype: object, File        938.tif
#  Vehicle         149
#  Airplane          0
#  Ship              0
#  Name: 938, dtype: object, File        941.tif
#  Vehicle          32
#  Airplane          0
#  Ship              0
#  Name: 941, dtype: object, File        946.tif
#  Vehicle          37
#  Airplane          0
#  Ship              0
#  Name: 946, dtype: object, File        948.tif
#  Vehicle          77
#  Airplane          0
#  Ship              0
#  Name: 948, dtype: object, File        952.tif
#  Vehicle          92
#  Airplane          0
#  Ship              0
#  Name: 952, dtype: object, File        955.tif
#  Vehicle         106
#  Airplane          0
#  Ship              0
#  Name: 955, dtype: object, File        956.tif
#  Vehicle          11
#  Airplane          0
#  Ship              0
#  Name: 956, dtype: object, File        957.tif
#  Vehicle          69
#  Airplane          0
#  Ship              0
#  Name: 957, dtype: object, File        959.tif
#  Vehicle          46
#  Airplane          0
#  Ship              0
#  Name: 959, dtype: object, File        960.tif
#  Vehicle         111
#  Airplane          0
#  Ship              0
#  Name: 960, dtype: object, File        964.tif
#  Vehicle          96
#  Airplane          0
#  Ship              0
#  Name: 964, dtype: object, File        965.tif
#  Vehicle          49
#  Airplane          0
#  Ship              0
#  Name: 965, dtype: object, File        966.tif
#  Vehicle          79
#  Airplane          0
#  Ship              0
#  Name: 966, dtype: object, File        967.tif
#  Vehicle           4
#  Airplane          0
#  Ship              0
#  Name: 967, dtype: object, File        969.tif
#  Vehicle         611
#  Airplane          0
#  Ship              0
#  Name: 969, dtype: object, File        971.tif
#  Vehicle          25
#  Airplane          0
#  Ship              0
#  Name: 971, dtype: object, File        972.tif
#  Vehicle          21
#  Airplane          0
#  Ship              0
#  Name: 972, dtype: object, File        974.tif
#  Vehicle          44
#  Airplane          0
#  Ship              0
#  Name: 974, dtype: object, File        976.tif
#  Vehicle         272
#  Airplane          0
#  Ship              0
# ...
#  Vehicle           47
#  Airplane           0
#  Ship               0
#  Name: 1453, dtype: object, File        1454.tif
#  Vehicle          187
#  Airplane           0
#  Ship               0
#  Name: 1454, dtype: object, File        1458.tif
#  Vehicle           47
#  Airplane           0
#  Ship               0
#  Name: 1458, dtype: object, File        1459.tif
#  Vehicle          133
#  Airplane           0
#  Ship               0
#  Name: 1459, dtype: object, File        1461.tif
#  Vehicle          112
#  Airplane           0
#  Ship               0
#  Name: 1461, dtype: object, File        1462.tif
#  Vehicle          205
#  Airplane           0
#  Ship               0
#  Name: 1462, dtype: object, File        1463.tif
#  Vehicle           57
#  Airplane           0
#  Ship               0
#  Name: 1463, dtype: object, File        1464.tif
#  Vehicle           13
#  Airplane           0
#  Ship               0
#  Name: 1464, dtype: object, File        1465.tif
#  Vehicle           50
#  Airplane           0
#  Ship               0
#  Name: 1465, dtype: object, File        1472.tif
#  Vehicle            5
#  Airplane           0
#  Ship               0
#  Name: 1472, dtype: object, File        1474.tif
#  Vehicle           83
#  Airplane           0
#  Ship               0
#  Name: 1474, dtype: object, File        1475.tif
#  Vehicle           26
#  Airplane           0
#  Ship               0
#  Name: 1475, dtype: object, File        1476.tif
#  Vehicle           54
#  Airplane           0
#  Ship               0
#  Name: 1476, dtype: object, File        1477.tif
#  Vehicle           75
#  Airplane           0
#  Ship               0
#  Name: 1477, dtype: object, File        1483.tif
#  Vehicle            9
#  Airplane           0
#  Ship               0
#  Name: 1483, dtype: object, File        1485.tif
#  Vehicle           23
#  Airplane           0
#  Ship               0
#  Name: 1485, dtype: object, File        1486.tif
#  Vehicle           42
#  Airplane           0
#  Ship               0
#  Name: 1486, dtype: object, File        1488.tif
#  Vehicle            1
#  Airplane           0
#  Ship               0
#  Name: 1488, dtype: object, File        1490.tif
#  Vehicle           48
#  Airplane           0
#  Ship               0
#  Name: 1490, dtype: object, File        1491.tif
#  Vehicle           31
#  Airplane           0
#  Ship               0
#  Name: 1491, dtype: object, File        1492.tif
#  Vehicle           27
#  Airplane           0
#  Ship               0
#  Name: 1492, dtype: object, File        1497.tif
#  Vehicle           69
#  Airplane           0
#  Ship               0
#  Name: 1497, dtype: object, File        1498.tif
#  Vehicle          205
#  Airplane           0
#  Ship               0
#  Name: 1498, dtype: object, File        1499.tif
#  Vehicle          120
#  Airplane           0
#  Ship               0
#  Name: 1499, dtype: object, File        1500.tif
#  Vehicle           39
#  Airplane           0
#  Ship               0
#  Name: 1500, dtype: object, File        1504.tif
#  Vehicle            3
#  Airplane           0
#  Ship               0
#  Name: 1504, dtype: object, File        1506.tif
#  Vehicle           31
#  Airplane           0
#  Ship               0
#  Name: 1506, dtype: object, File        1507.tif
#  Vehicle           62
#  Airplane           0
#  Ship               0
#  Name: 1507, dtype: object, File        1509.tif
#  Vehicle           33
#  Airplane           0
#  Ship               0
#  Name: 1509, dtype: object, File        1511.tif
#  Vehicle          114
#  Airplane           0
#  Ship               0
#  Name: 1511, dtype: object, File        1517.tif
#  Vehicle          164
#  Airplane           0
#  Ship               0
#  Name: 1517, dtype: object, File        1518.tif
#  Vehicle           71
#  Airplane           0
#  Ship               0
#  Name: 1518, dtype: object, File        1519.tif
#  Vehicle          119
#  Airplane           0
#  Ship               0
#  Name: 1519, dtype: object, File        1520.tif
#  Vehicle          256
#  Airplane           0
#  Ship               0
#  Name: 1520, dtype: object, File        1521.tif
#  Vehicle           30
#  Airplane           0
#  Ship               0
#  Name: 1521, dtype: object, File        1522.tif
#  Vehicle           39
#  Airplane           0
#  Ship               0
#  Name: 1522, dtype: object, File        1525.tif
#  Vehicle           73
#  Airplane           0
#  Ship               0
#  Name: 1525, dtype: object, File        1527.tif
#  Vehicle           52
#  Airplane           0
#  Ship               0
#  Name: 1527, dtype: object, File        1530.tif
#  Vehicle           92
#  Airplane           0
#  Ship               0
#  Name: 1530, dtype: object, File        1532.tif
#  Vehicle           44
#  Airplane           0
#  Ship               0
#  Name: 1532, dtype: object, File        1533.tif
#  Vehicle           68
#  Airplane           0
#  Ship               0
#  Name: 1533, dtype: object, File        1534.tif
#  Vehicle          330
#  Airplane           0
#  Ship               0
#  Name: 1534, dtype: object, File        1535.tif
#  Vehicle           94
#  Airplane           0
#  Ship               0
#  Name: 1535, dtype: object, File        1536.tif
#  Vehicle          114
#  Airplane           0
#  Ship               0
#  Name: 1536, dtype: object, File        1539.tif
#  Vehicle          221
#  Airplane           0
#  Ship               0
#  Name: 1539, dtype: object, File        1540.tif
#  Vehicle           60
#  Airplane           0
#  Ship               0
#  Name: 1540, dtype: object, File        1541.tif
#  Vehicle            2
#  Airplane           0
#  Ship               0
#  Name: 1541, dtype: object, File        1543.tif
#  Vehicle           54
#  Airplane           0
#  Ship               0
#  Name: 1543, dtype: object, File        1544.tif
#  Vehicle            1
#  Airplane           0
#  Ship               0
#  Name: 1544, dtype: object, File        1545.tif
#  Vehicle           16
#  Airplane           0
#  Ship               0
#  Name: 1545, dtype: object, File        1546.tif
#  Vehicle           40
#  Airplane           0
#  Ship               0
#  Name: 1546, dtype: object, File        1549.tif
#  Vehicle           31
#  Airplane           0
#  Ship               0
#  Name: 1549, dtype: object, File        1551.tif
#  Vehicle           68
#  Airplane           0
#  Ship               0
#  Name: 1551, dtype: object, File        1553.tif
#  Vehicle           79
#  Airplane           0
#  Ship               0
#  Name: 1553, dtype: object, File        1555.tif
#  Vehicle           72
#  Airplane           0
#  Ship               0
#  Name: 1555, dtype: object, File        1559.tif
#  Vehicle           16
#  Airplane           0
#  Ship               0
#  Name: 1559, dtype: object, File        1560.tif
#  Vehicle            3
#  Airplane           0
#  Ship               0
#  Name: 1560, dtype: object, File        1562.tif
#  Vehicle           62
#  Airplane           0
#  Ship               0
#  Name: 1562, dtype: object, File        1563.tif
#  Vehicle           55
#  Airplane           0
#  Ship               0
#  Name: 1563, dtype: object, File        1564.tif
#  Vehicle          600
#  Airplane           0
#  Ship               0
#  Name: 1564, dtype: object, File        1565.tif
#  Vehicle           35
#  Airplane           0
#  Ship               0
#  Name: 1565, dtype: object, File        1567.tif
#  Vehicle           39
#  Airplane           0
#  Ship               0
#  Name: 1567, dtype: object, File        1571.tif
#  Vehicle           98
#  Airplane           0
#  Ship               0
#  Name: 1571, dtype: object, File        1572.tif
#  Vehicle          124
#  Airplane           0
#  Ship               0
#  Name: 1572, dtype: object, File        1576.tif
#  Vehicle           15
#  Airplane           0
#  Ship               0
#  Name: 1576, dtype: object, File        1580.tif
#  Vehicle           14
#  Airplane           0
#  Ship               0
#  Name: 1580, dtype: object, File        1583.tif
#  Vehicle           59
#  Airplane           0
#  Ship               0
#  Name: 1583, dtype: object, File        1586.tif
#  Vehicle          148
#  Airplane           0
#  Ship               0
#  Name: 1586, dtype: object, File        1587.tif
#  Vehicle           21
#  Airplane           0
#  Ship               0
#  Name: 1587, dtype: object, File        1588.tif
#  Vehicle           79
#  Airplane           0
#  Ship               0
#  Name: 1588, dtype: object, File        1590.tif
#  Vehicle          116
#  Airplane           0
#  Ship               0
#  Name: 1590, dtype: object, File        1593.tif
#  Vehicle          114
#  Airplane           0
#  Ship               0
#  Name: 1593, dtype: object, File        1595.tif
#  Vehicle            5
#  Airplane           0
#  Ship               0
#  Name: 1595, dtype: object, File        1596.tif
#  Vehicle           37
#  Airplane           0
#  Ship               0
#  Name: 1596, dtype: object, File        1599.tif
#  Vehicle           99
#  Airplane           0
#  Ship               0
#  Name: 1599, dtype: object, File        1600.tif
#  Vehicle           21
#  Airplane           0
#  Ship               0
#  Name: 1600, dtype: object, File        1601.tif
#  Vehicle            2
#  Airplane           0
#  Ship               0
#  Name: 1601, dtype: object, File        1602.tif
#  Vehicle           82
#  Airplane           0
#  Ship               0
#  Name: 1602, dtype: object, File        1604.tif
#  Vehicle           79
#  Airplane           0
#  Ship               0
#  Name: 1604, dtype: object, File        1606.tif
#  Vehicle           74
#  Airplane           0
#  Ship               0
#  Name: 1606, dtype: object, File        1609.tif
#  Vehicle          126
#  Airplane           0
#  Ship               0
#  Name: 1609, dtype: object, File        1610.tif
#  Vehicle            1
#  Airplane           0
#  Ship               0
#  Name: 1610, dtype: object, File        1611.tif
#  Vehicle          208
#  Airplane           0
#  Ship               0
#  Name: 1611, dtype: object, File        1612.tif
#  Vehicle          115
#  Airplane           0
#  Ship               0
#  Name: 1612, dtype: object, File        1613.tif
#  Vehicle          158
#  Airplane           0
#  Ship               0
#  Name: 1613, dtype: object, File        1616.tif
#  Vehicle           64
#  Airplane           0
#  Ship               0
#  Name: 1616, dtype: object, File        1617.tif
#  Vehicle           11
#  Airplane           0
#  Ship               0
#  Name: 1617, dtype: object, File        1619.tif
#  Vehicle           61
#  Airplane           0
#  Ship               0
#  Name: 1619, dtype: object, File        1622.tif
#  Vehicle           55
#  Airplane           0
#  Ship               0
#  Name: 1622, dtype: object, File        1623.tif
#  Vehicle           35
#  Airplane           0
#  Ship               0
#  Name: 1623, dtype: object, File        1625.tif
#  Vehicle            7
#  Airplane           0
#  Ship               0
#  Name: 1625, dtype: object, File        1626.tif
#  Vehicle           44
#  Airplane           0
#  Ship               0
#  Name: 1626, dtype: object, File        1628.tif
#  Vehicle            1
#  Airplane           0
#  Ship               0
#  Name: 1628, dtype: object, File        1631.tif
#  Vehicle          119
#  Airplane           0
#  Ship               0
#  Name: 1631, dtype: object, File        1632.tif
#  Vehicle           24
#  Airplane           0
#  Ship               0
#  Name: 1632, dtype: object, File        1635.tif
#  Vehicle            7
#  Airplane           0
#  Ship               0
#  Name: 1635, dtype: object, File        1637.tif
#  Vehicle          190
#  Airplane           0
#  Ship               0
#  Name: 1637, dtype: object, File        1639.tif
#  Vehicle           31
#  Airplane           0
#  Ship               0
#  Name: 1639, dtype: object, File        1643.tif
#  Vehicle           48
#  Airplane           0
#  Ship               0
#  Name: 1643, dtype: object, File        1645.tif
#  Vehicle           43
#  Airplane           0
#  Ship               0
#  Name: 1645, dtype: object, File        1646.tif
#  Vehicle          170
#  Airplane           0
#  Ship               0
#  Name: 1646, dtype: object, File        1648.tif
#  Vehicle           88
#  Airplane           0
#  Ship               0
#  Name: 1648, dtype: object, File        1651.tif
#  Vehicle           59
#  Airplane           0
#  Ship               0
#  Name: 1651, dtype: object, File        1652.tif
#  Vehicle           27
#  Airplane           0
#  Ship               0
#  Name: 1652, dtype: object, File        1655.tif
#  Vehicle          200
#  Airplane           0
#  Ship               0
#  Name: 1655, dtype: object, File        1656.tif
#  Vehicle           27
#  Airplane           0
#  Ship               0
#  Name: 1656, dtype: object, File        1657.tif
#  Vehicle           63
#  Airplane           0
#  Ship               0
#  Name: 1657, dtype: object, File        1658.tif
#  Vehicle           38
#  Airplane           0
#  Ship               0
#  Name: 1658, dtype: object, File        1660.tif
#  Vehicle           54
#  Airplane           0
#  Ship               0
#  Name: 1660, dtype: object, File        1662.tif
#  Vehicle           26
#  Airplane           0
#  Ship               0
#  Name: 1662, dtype: object, File        1665.tif
#  Vehicle           64
#  Airplane           0
#  Ship               0
#  Name: 1665, dtype: object, File        1667.tif
#  Vehicle          219
#  Airplane           0
#  Ship               0
#  Name: 1667, dtype: object, File        1669.tif
#  Vehicle           62
#  Airplane           0
#  Ship               0
#  Name: 1669, dtype: object, File        1670.tif
#  Vehicle          151
#  Airplane           0
#  Ship               0
#  Name: 1670, dtype: object, File        1671.tif
#  Vehicle            3
#  Airplane           0
#  Ship               0
#  Name: 1671, dtype: object, File        1673.tif
#  Vehicle           42
#  Airplane           0
#  Ship               0
#  Name: 1673, dtype: object, File        1675.tif
#  Vehicle          158
#  Airplane           0
#  Ship               0
#  Name: 1675, dtype: object, File        1681.tif
#  Vehicle          146
#  Airplane           0
#  Ship               0
#  Name: 1681, dtype: object, File        1686.tif
#  Vehicle           92
#  Airplane           0
#  Ship               0
#  Name: 1686, dtype: object, File        1693.tif
#  Vehicle           53
#  Airplane           0
#  Ship               0
#  Name: 1693, dtype: object, File        1695.tif
#  Vehicle          101
#  Airplane           0
#  Ship               0
#  Name: 1695, dtype: object, File        1696.tif
#  Vehicle           31
#  Airplane           0
#  Ship               0
#  Name: 1696, dtype: object, File        1698.tif
#  Vehicle           91
#  Airplane           0
#  Ship               0
#  Name: 1698, dtype: object, File        1700.tif
#  Vehicle          101
#  Airplane           0
#  Ship               0
#  Name: 1700, dtype: object, File        1701.tif
#  Vehicle          111
#  Airplane           0
#  Ship               0
#  Name: 1701, dtype: object, File        1702.tif
#  Vehicle          166
#  Airplane           0
#  Ship               0
#  Name: 1702, dtype: object, File        1703.tif
#  Vehicle           97
#  Airplane           0
#  Ship               0
#  Name: 1703, dtype: object, File        1708.tif
#  Vehicle           19
#  Airplane           0
#  Ship               0
#  Name: 1708, dtype: object, File        1709.tif
#  Vehicle           55
#  Airplane           0
#  Ship               0
#  Name: 1709, dtype: object, File        1710.tif
#  Vehicle          186
#  Airplane           0
#  Ship               0
#  Name: 1710, dtype: object, File        1714.tif
#  Vehicle          175
#  Airplane           0
#  Ship               0
#  Name: 1714, dtype: object, File        1715.tif
#  Vehicle            4
#  Airplane           0
#  Ship               0
#  Name: 1715, dtype: object, File        1716.tif
#  Vehicle           47
#  Airplane           0
#  Ship               0
#  Name: 1716, dtype: object, File        1717.tif
#  Vehicle            7
#  Airplane           0
#  Ship               0
#  Name: 1717, dtype: object, File        1721.tif
#  Vehicle           16
#  Airplane           0
#  Ship               0
#  Name: 1721, dtype: object, File        1722.tif
#  Vehicle           92
#  Airplane           0
#  Ship               0
#  Name: 1722, dtype: object, File        1724.tif
#  Vehicle           23
#  Airplane           0
#  Ship               0
#  Name: 1724, dtype: object, File        1725.tif
#  Vehicle           31
#  Airplane           0
#  Ship               0
#  Name: 1725, dtype: object, File        1727.tif
#  Vehicle          174
#  Airplane           0
#  Ship               0
#  Name: 1727, dtype: object]

# %%
only_airplane
# Out:
# [File        2.tif
#  Vehicle         0
#  Airplane        3
#  Ship            0
#  Name: 2, dtype: object, File        4.tif
#  Vehicle         0
#  Airplane        2
#  Ship            0
#  Name: 4, dtype: object, File        5.tif
#  Vehicle         0
#  Airplane        1
#  Ship            0
#  Name: 5, dtype: object, File        7.tif
#  Vehicle         0
#  Airplane       23
#  Ship            0
#  Name: 7, dtype: object, File        19.tif
#  Vehicle          0
#  Airplane         1
#  Ship             0
#  Name: 19, dtype: object, File        20.tif
#  Vehicle          0
#  Airplane         3
#  Ship             0
#  Name: 20, dtype: object, File        32.tif
#  Vehicle          0
#  Airplane         2
#  Ship             0
#  Name: 32, dtype: object, File        34.tif
#  Vehicle          0
#  Airplane         4
#  Ship             0
#  Name: 34, dtype: object, File        42.tif
#  Vehicle          0
#  Airplane         2
#  Ship             0
#  Name: 42, dtype: object, File        46.tif
#  Vehicle          0
#  Airplane         5
#  Ship             0
#  Name: 46, dtype: object, File        48.tif
#  Vehicle          0
#  Airplane         6
#  Ship             0
#  Name: 48, dtype: object, File        49.tif
#  Vehicle          0
#  Airplane         7
#  Ship             0
#  Name: 49, dtype: object, File        52.tif
#  Vehicle          0
#  Airplane         6
#  Ship             0
#  Name: 52, dtype: object, File        54.tif
#  Vehicle          0
#  Airplane         1
#  Ship             0
#  Name: 54, dtype: object, File        55.tif
#  Vehicle          0
#  Airplane         4
#  Ship             0
#  Name: 55, dtype: object, File        61.tif
#  Vehicle          0
#  Airplane         1
#  Ship             0
#  Name: 61, dtype: object, File        62.tif
#  Vehicle          0
#  Airplane         8
#  Ship             0
#  Name: 62, dtype: object, File        67.tif
#  Vehicle          0
#  Airplane         1
#  Ship             0
#  Name: 67, dtype: object, File        73.tif
#  Vehicle          0
#  Airplane         7
#  Ship             0
#  Name: 73, dtype: object, File        78.tif
#  Vehicle          0
#  Airplane         1
#  Ship             0
#  Name: 78, dtype: object, File        81.tif
#  Vehicle          0
#  Airplane         1
#  Ship             0
#  Name: 81, dtype: object, File        86.tif
#  Vehicle          0
#  Airplane         5
#  Ship             0
#  Name: 86, dtype: object, File        89.tif
#  Vehicle          0
#  Airplane         1
#  Ship             0
#  Name: 89, dtype: object, File        96.tif
#  Vehicle          0
#  Airplane         1
#  Ship             0
#  Name: 96, dtype: object, File        98.tif
#  Vehicle          0
#  Airplane         4
#  Ship             0
#  Name: 98, dtype: object, File        104.tif
#  Vehicle           0
#  Airplane          6
#  Ship              0
#  Name: 104, dtype: object, File        106.tif
#  Vehicle           0
#  Airplane          6
#  Ship              0
#  Name: 106, dtype: object, File        114.tif
#  Vehicle           0
#  Airplane          4
#  Ship              0
#  Name: 114, dtype: object, File        116.tif
#  Vehicle           0
#  Airplane          3
#  Ship              0
#  Name: 116, dtype: object, File        123.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 123, dtype: object, File        131.tif
#  Vehicle           0
#  Airplane          4
#  Ship              0
#  Name: 131, dtype: object, File        135.tif
#  Vehicle           0
#  Airplane          5
#  Ship              0
#  Name: 135, dtype: object, File        137.tif
#  Vehicle           0
#  Airplane          4
#  Ship              0
#  Name: 137, dtype: object, File        138.tif
#  Vehicle           0
#  Airplane          3
#  Ship              0
#  Name: 138, dtype: object, File        142.tif
#  Vehicle           0
#  Airplane          7
#  Ship              0
#  Name: 142, dtype: object, File        146.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 146, dtype: object, File        148.tif
#  Vehicle           0
#  Airplane          6
#  Ship              0
#  Name: 148, dtype: object, File        151.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 151, dtype: object, File        156.tif
#  Vehicle           0
#  Airplane          6
#  Ship              0
#  Name: 156, dtype: object, File        157.tif
#  Vehicle           0
#  Airplane          7
#  Ship              0
#  Name: 157, dtype: object, File        158.tif
#  Vehicle           0
#  Airplane         14
#  Ship              0
#  Name: 158, dtype: object, File        163.tif
#  Vehicle           0
#  Airplane          6
#  Ship              0
#  Name: 163, dtype: object, File        164.tif
#  Vehicle           0
#  Airplane          7
#  Ship              0
#  Name: 164, dtype: object, File        167.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 167, dtype: object, File        170.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 170, dtype: object, File        183.tif
#  Vehicle           0
#  Airplane          3
#  Ship              0
#  Name: 183, dtype: object, File        187.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 187, dtype: object, File        193.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 193, dtype: object, File        195.tif
#  Vehicle           0
#  Airplane          5
#  Ship              0
#  Name: 195, dtype: object, File        196.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 196, dtype: object, File        203.tif
#  Vehicle           0
#  Airplane          5
#  Ship              0
#  Name: 203, dtype: object, File        205.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 205, dtype: object, File        207.tif
#  Vehicle           0
#  Airplane          5
#  Ship              0
#  Name: 207, dtype: object, File        212.tif
#  Vehicle           0
#  Airplane          4
#  Ship              0
#  Name: 212, dtype: object, File        221.tif
#  Vehicle           0
#  Airplane          6
#  Ship              0
#  Name: 221, dtype: object, File        222.tif
#  Vehicle           0
#  Airplane         30
#  Ship              0
#  Name: 222, dtype: object, File        223.tif
#  Vehicle           0
#  Airplane         13
#  Ship              0
#  Name: 223, dtype: object, File        235.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 235, dtype: object, File        239.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 239, dtype: object, File        245.tif
#  Vehicle           0
#  Airplane         10
#  Ship              0
#  Name: 245, dtype: object, File        246.tif
#  Vehicle           0
#  Airplane          6
#  Ship              0
#  Name: 246, dtype: object, File        248.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 248, dtype: object, File        251.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 251, dtype: object, File        254.tif
#  Vehicle           0
#  Airplane          7
#  Ship              0
#  Name: 254, dtype: object, File        255.tif
#  Vehicle           0
#  Airplane          5
#  Ship              0
#  Name: 255, dtype: object, File        259.tif
#  Vehicle           0
#  Airplane         12
#  Ship              0
#  Name: 259, dtype: object, File        268.tif
#  Vehicle           0
#  Airplane          9
#  Ship              0
#  Name: 268, dtype: object, File        271.tif
#  Vehicle           0
#  Airplane          6
#  Ship              0
#  Name: 271, dtype: object, File        272.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 272, dtype: object, File        273.tif
#  Vehicle           0
#  Airplane         11
#  Ship              0
#  Name: 273, dtype: object, File        274.tif
#  Vehicle           0
#  Airplane          6
#  Ship              0
#  Name: 274, dtype: object, File        276.tif
#  Vehicle           0
#  Airplane          3
#  Ship              0
#  Name: 276, dtype: object, File        279.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 279, dtype: object, File        282.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 282, dtype: object, File        284.tif
#  Vehicle           0
#  Airplane         18
#  Ship              0
#  Name: 284, dtype: object, File        295.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 295, dtype: object, File        303.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 303, dtype: object, File        306.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 306, dtype: object, File        310.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 310, dtype: object, File        318.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 318, dtype: object, File        324.tif
#  Vehicle           0
#  Airplane          5
#  Ship              0
#  Name: 324, dtype: object, File        326.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 326, dtype: object, File        333.tif
#  Vehicle           0
#  Airplane          4
#  Ship              0
#  Name: 333, dtype: object, File        337.tif
#  Vehicle           0
#  Airplane          4
#  Ship              0
#  Name: 337, dtype: object, File        339.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 339, dtype: object, File        340.tif
#  Vehicle           0
#  Airplane          3
#  Ship              0
#  Name: 340, dtype: object, File        358.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 358, dtype: object, File        365.tif
#  Vehicle           0
#  Airplane          3
#  Ship              0
#  Name: 365, dtype: object, File        366.tif
#  Vehicle           0
#  Airplane          7
#  Ship              0
#  Name: 366, dtype: object, File        370.tif
#  Vehicle           0
#  Airplane          7
#  Ship              0
#  Name: 370, dtype: object, File        372.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 372, dtype: object, File        378.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 378, dtype: object, File        383.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 383, dtype: object, File        388.tif
#  Vehicle           0
#  Airplane          5
#  Ship              0
#  Name: 388, dtype: object, File        394.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 394, dtype: object, File        406.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 406, dtype: object, File        424.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 424, dtype: object, File        431.tif
#  Vehicle           0
#  Airplane          9
#  Ship              0
#  Name: 431, dtype: object, File        432.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 432, dtype: object, File        440.tif
#  Vehicle           0
#  Airplane          9
#  Ship              0
#  Name: 440, dtype: object, File        446.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 446, dtype: object, File        453.tif
#  Vehicle           0
#  Airplane          9
#  Ship              0
#  Name: 453, dtype: object, File        457.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 457, dtype: object, File        459.tif
#  Vehicle           0
#  Airplane          3
#  Ship              0
#  Name: 459, dtype: object, File        466.tif
#  Vehicle           0
#  Airplane         13
#  Ship              0
#  Name: 466, dtype: object, File        467.tif
#  Vehicle           0
#  Airplane          6
#  Ship              0
#  Name: 467, dtype: object, File        470.tif
#  Vehicle           0
#  Airplane          4
#  Ship              0
#  Name: 470, dtype: object, File        472.tif
#  Vehicle           0
#  Airplane          6
#  Ship              0
#  Name: 472, dtype: object, File        478.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 478, dtype: object, File        480.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 480, dtype: object, File        482.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 482, dtype: object, File        484.tif
#  Vehicle           0
#  Airplane          5
#  Ship              0
#  Name: 484, dtype: object, File        488.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 488, dtype: object, File        493.tif
#  Vehicle           0
#  Airplane         20
#  Ship              0
#  Name: 493, dtype: object, File        497.tif
#  Vehicle           0
#  Airplane          5
#  Ship              0
#  Name: 497, dtype: object, File        500.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 500, dtype: object, File        515.tif
#  Vehicle           0
#  Airplane          3
#  Ship              0
#  Name: 515, dtype: object, File        521.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 521, dtype: object, File        522.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 522, dtype: object, File        523.tif
#  Vehicle           0
#  Airplane          3
#  Ship              0
#  Name: 523, dtype: object, File        524.tif
#  Vehicle           0
#  Airplane         53
#  Ship              0
#  Name: 524, dtype: object, File        525.tif
#  Vehicle           0
#  Airplane          4
#  Ship              0
#  Name: 525, dtype: object, File        528.tif
#  Vehicle           0
#  Airplane          3
#  Ship              0
#  Name: 528, dtype: object, File        531.tif
#  Vehicle           0
#  Airplane          8
#  Ship              0
#  Name: 531, dtype: object, File        537.tif
#  Vehicle           0
#  Airplane          4
#  Ship              0
#  Name: 537, dtype: object, File        538.tif
#  Vehicle           0
#  Airplane          7
#  Ship              0
#  Name: 538, dtype: object, File        541.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 541, dtype: object, File        543.tif
#  Vehicle           0
#  Airplane          3
#  Ship              0
#  Name: 543, dtype: object, File        544.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 544, dtype: object, File        549.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 549, dtype: object, File        552.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 552, dtype: object, File        564.tif
#  Vehicle           0
#  Airplane         13
#  Ship              0
#  Name: 564, dtype: object, File        566.tif
#  Vehicle           0
#  Airplane          7
#  Ship              0
#  Name: 566, dtype: object, File        579.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 579, dtype: object, File        582.tif
#  Vehicle           0
#  Airplane          4
#  Ship              0
#  Name: 582, dtype: object, File        585.tif
#  Vehicle           0
#  Airplane          5
#  Ship              0
#  Name: 585, dtype: object, File        587.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 587, dtype: object, File        599.tif
#  Vehicle           0
#  Airplane         20
#  Ship              0
#  Name: 599, dtype: object, File        601.tif
#  Vehicle           0
#  Airplane          8
#  Ship              0
#  Name: 601, dtype: object, File        605.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 605, dtype: object, File        606.tif
#  Vehicle           0
#  Airplane          5
#  Ship              0
#  Name: 606, dtype: object, File        607.tif
#  Vehicle           0
#  Airplane          7
#  Ship              0
#  Name: 607, dtype: object, File        622.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 622, dtype: object, File        634.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 634, dtype: object, File        644.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 644, dtype: object, File        645.tif
#  Vehicle           0
#  Airplane          3
#  Ship              0
#  Name: 645, dtype: object, File        649.tif
#  Vehicle           0
#  Airplane          5
#  Ship              0
#  Name: 649, dtype: object, File        650.tif
#  Vehicle           0
#  Airplane         15
#  Ship              0
#  Name: 650, dtype: object, File        651.tif
#  Vehicle           0
#  Airplane          3
#  Ship              0
#  Name: 651, dtype: object, File        654.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 654, dtype: object, File        660.tif
#  Vehicle           0
#  Airplane          8
#  Ship              0
#  Name: 660, dtype: object, File        664.tif
#  Vehicle           0
#  Airplane          6
#  Ship              0
#  Name: 664, dtype: object, File        674.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 674, dtype: object, File        679.tif
#  Vehicle           0
#  Airplane          8
#  Ship              0
#  Name: 679, dtype: object, File        684.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 684, dtype: object, File        685.tif
#  Vehicle           0
#  Airplane         13
#  Ship              0
#  Name: 685, dtype: object, File        686.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 686, dtype: object, File        688.tif
#  Vehicle           0
#  Airplane          3
#  Ship              0
#  Name: 688, dtype: object, File        691.tif
#  Vehicle           0
#  Airplane          9
#  Ship              0
#  Name: 691, dtype: object, File        695.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 695, dtype: object, File        703.tif
#  Vehicle           0
#  Airplane          6
#  Ship              0
#  Name: 703, dtype: object, File        704.tif
#  Vehicle           0
#  Airplane          4
#  Ship              0
#  Name: 704, dtype: object, File        716.tif
#  Vehicle           0
#  Airplane          7
#  Ship              0
#  Name: 716, dtype: object, File        728.tif
#  Vehicle           0
#  Airplane          8
#  Ship              0
#  Name: 728, dtype: object, File        732.tif
#  Vehicle           0
#  Airplane          5
#  Ship              0
#  Name: 732, dtype: object, File        739.tif
#  Vehicle           0
#  Airplane         17
#  Ship              0
#  Name: 739, dtype: object, File        741.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 741, dtype: object, File        746.tif
#  Vehicle           0
#  Airplane          4
#  Ship              0
#  Name: 746, dtype: object, File        747.tif
#  Vehicle           0
#  Airplane          4
#  Ship              0
#  Name: 747, dtype: object, File        753.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 753, dtype: object, File        755.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 755, dtype: object, File        760.tif
#  Vehicle           0
#  Airplane         25
#  Ship              0
#  Name: 760, dtype: object, File        766.tif
#  Vehicle           0
#  Airplane          9
#  Ship              0
#  Name: 766, dtype: object, File        771.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 771, dtype: object, File        777.tif
#  Vehicle           0
#  Airplane          5
#  Ship              0
#  Name: 777, dtype: object, File        778.tif
#  Vehicle           0
#  Airplane          8
#  Ship              0
#  Name: 778, dtype: object, File        782.tif
#  Vehicle           0
#  Airplane          6
#  Ship              0
#  Name: 782, dtype: object, File        784.tif
#  Vehicle           0
#  Airplane          4
#  Ship              0
#  Name: 784, dtype: object, File        789.tif
#  Vehicle           0
#  Airplane         14
#  Ship              0
#  Name: 789, dtype: object, File        790.tif
#  Vehicle           0
#  Airplane          6
#  Ship              0
#  Name: 790, dtype: object, File        794.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 794, dtype: object, File        804.tif
#  Vehicle           0
#  Airplane          9
#  Ship              0
#  Name: 804, dtype: object, File        806.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 806, dtype: object, File        809.tif
#  Vehicle           0
#  Airplane         11
#  Ship              0
#  Name: 809, dtype: object, File        813.tif
#  Vehicle           0
#  Airplane          4
#  Ship              0
#  Name: 813, dtype: object, File        819.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 819, dtype: object, File        820.tif
#  Vehicle           0
#  Airplane          5
#  Ship              0
#  Name: 820, dtype: object, File        822.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 822, dtype: object, File        833.tif
#  Vehicle           0
#  Airplane          8
#  Ship              0
#  Name: 833, dtype: object, File        835.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 835, dtype: object, File        837.tif
#  Vehicle           0
#  Airplane          5
#  Ship              0
#  Name: 837, dtype: object, File        839.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 839, dtype: object, File        851.tif
#  Vehicle           0
#  Airplane          9
#  Ship              0
#  Name: 851, dtype: object, File        855.tif
#  Vehicle           0
#  Airplane          4
#  Ship              0
#  Name: 855, dtype: object, File        857.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 857, dtype: object, File        860.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 860, dtype: object, File        861.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 861, dtype: object, File        880.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 880, dtype: object, File        907.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 907, dtype: object, File        910.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 910, dtype: object, File        915.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 915, dtype: object, File        923.tif
#  Vehicle           0
#  Airplane         26
#  Ship              0
#  Name: 923, dtype: object, File        924.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 924, dtype: object, File        939.tif
#  Vehicle           0
#  Airplane          4
#  Ship              0
#  Name: 939, dtype: object, File        942.tif
#  Vehicle           0
#  Airplane          4
#  Ship              0
#  Name: 942, dtype: object, File        944.tif
#  Vehicle           0
#  Airplane          3
#  Ship              0
#  Name: 944, dtype: object, File        945.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 945, dtype: object, File        947.tif
#  Vehicle           0
#  Airplane          4
#  Ship              0
#  Name: 947, dtype: object, File        949.tif
#  Vehicle           0
#  Airplane          5
#  Ship              0
#  Name: 949, dtype: object, File        970.tif
#  Vehicle           0
#  Airplane          6
#  Ship              0
#  Name: 970, dtype: object, File        975.tif
#  Vehicle           0
#  Airplane          8
#  Ship              0
#  Name: 975, dtype: object, File        977.tif
#  Vehicle           0
#  Airplane          1
#  Ship              0
#  Name: 977, dtype: object, File        983.tif
#  Vehicle           0
#  Airplane         64
#  Ship              0
#  Name: 983, dtype: object, File        991.tif
#  Vehicle           0
#  Airplane          2
#  Ship              0
#  Name: 991, dtype: object, File        994.tif
#  Vehicle           0
#  Airplane         10
#  Ship              0
#  Name: 994, dtype: object, File        997.tif
#  Vehicle           0
#  Airplane          4
#  Ship              0
#  Name: 997, dtype: object, File        999.tif
#  Vehicle           0
#  Airplane         14
#  Ship              0
#  Name: 999, dtype: object, File        1002.tif
#  Vehicle            0
#  Airplane           6
#  Ship               0
#  Name: 1002, dtype: object, File        1004.tif
#  Vehicle            0
#  Airplane           6
#  Ship               0
#  Name: 1004, dtype: object, File        1007.tif
#  Vehicle            0
#  Airplane           6
#  Ship               0
#  Name: 1007, dtype: object, File        1008.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1008, dtype: object, File        1009.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1009, dtype: object, File        1016.tif
#  Vehicle            0
#  Airplane           3
#  Ship               0
#  Name: 1016, dtype: object, File        1017.tif
#  Vehicle            0
#  Airplane           6
#  Ship               0
#  Name: 1017, dtype: object, File        1019.tif
#  Vehicle            0
#  Airplane           5
#  Ship               0
#  Name: 1019, dtype: object, File        1023.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1023, dtype: object, File        1026.tif
#  Vehicle            0
#  Airplane           8
#  Ship               0
#  Name: 1026, dtype: object, File        1028.tif
#  Vehicle            0
#  Airplane           8
#  Ship               0
#  Name: 1028, dtype: object, File        1029.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1029, dtype: object, File        1030.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1030, dtype: object, File        1032.tif
#  Vehicle            0
#  Airplane           4
#  Ship               0
#  Name: 1032, dtype: object, File        1033.tif
#  Vehicle            0
#  Airplane           3
#  Ship               0
#  Name: 1033, dtype: object, File        1037.tif
#  Vehicle            0
#  Airplane          13
#  Ship               0
#  Name: 1037, dtype: object, File        1043.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1043, dtype: object, File        1044.tif
#  Vehicle            0
#  Airplane           3
#  Ship               0
#  Name: 1044, dtype: object, File        1048.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1048, dtype: object, File        1068.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1068, dtype: object, File        1071.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1071, dtype: object, File        1076.tif
#  Vehicle            0
#  Airplane           6
#  Ship               0
#  Name: 1076, dtype: object, File        1093.tif
#  Vehicle            0
#  Airplane           3
#  Ship               0
#  Name: 1093, dtype: object, File        1095.tif
#  Vehicle            0
#  Airplane          12
#  Ship               0
#  Name: 1095, dtype: object, File        1099.tif
#  Vehicle            0
#  Airplane          12
#  Ship               0
#  Name: 1099, dtype: object, File        1101.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1101, dtype: object, File        1109.tif
#  Vehicle            0
#  Airplane           3
#  Ship               0
#  Name: 1109, dtype: object, File        1113.tif
#  Vehicle            0
#  Airplane           6
#  Ship               0
#  Name: 1113, dtype: object, File        1116.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1116, dtype: object, File        1120.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1120, dtype: object, File        1124.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1124, dtype: object, File        1125.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1125, dtype: object, File        1131.tif
#  Vehicle            0
#  Airplane           6
#  Ship               0
#  Name: 1131, dtype: object, File        1133.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1133, dtype: object, File        1137.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1137, dtype: object, File        1143.tif
#  Vehicle            0
#  Airplane           7
#  Ship               0
#  Name: 1143, dtype: object, File        1152.tif
#  Vehicle            0
#  Airplane           4
#  Ship               0
#  Name: 1152, dtype: object, File        1153.tif
#  Vehicle            0
#  Airplane           4
#  Ship               0
#  Name: 1153, dtype: object, File        1155.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1155, dtype: object, File        1156.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1156, dtype: object, File        1157.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1157, dtype: object, File        1163.tif
#  Vehicle            0
#  Airplane           3
#  Ship               0
#  Name: 1163, dtype: object, File        1164.tif
#  Vehicle            0
#  Airplane           4
#  Ship               0
#  Name: 1164, dtype: object, File        1165.tif
#  Vehicle            0
#  Airplane          16
#  Ship               0
#  Name: 1165, dtype: object, File        1166.tif
#  Vehicle            0
#  Airplane           7
#  Ship               0
#  Name: 1166, dtype: object, File        1171.tif
#  Vehicle            0
#  Airplane           5
#  Ship               0
#  Name: 1171, dtype: object, File        1175.tif
#  Vehicle            0
#  Airplane           9
#  Ship               0
#  Name: 1175, dtype: object, File        1176.tif
#  Vehicle            0
#  Airplane           3
#  Ship               0
#  Name: 1176, dtype: object, File        1183.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1183, dtype: object, File        1188.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1188, dtype: object, File        1208.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1208, dtype: object, File        1213.tif
#  Vehicle            0
#  Airplane          11
#  Ship               0
#  Name: 1213, dtype: object, File        1217.tif
#  Vehicle            0
#  Airplane           6
#  Ship               0
#  Name: 1217, dtype: object, File        1223.tif
#  Vehicle            0
#  Airplane           9
#  Ship               0
#  Name: 1223, dtype: object, File        1230.tif
#  Vehicle            0
#  Airplane           3
#  Ship               0
#  Name: 1230, dtype: object, File        1237.tif
#  Vehicle            0
#  Airplane           4
#  Ship               0
#  Name: 1237, dtype: object, File        1238.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1238, dtype: object, File        1244.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1244, dtype: object, File        1249.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1249, dtype: object, File        1253.tif
#  Vehicle            0
#  Airplane           7
#  Ship               0
#  Name: 1253, dtype: object, File        1257.tif
#  Vehicle            0
#  Airplane           4
#  Ship               0
#  Name: 1257, dtype: object, File        1259.tif
#  Vehicle            0
#  Airplane           6
#  Ship               0
#  Name: 1259, dtype: object, File        1264.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1264, dtype: object, File        1265.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1265, dtype: object, File        1266.tif
#  Vehicle            0
#  Airplane          13
#  Ship               0
#  Name: 1266, dtype: object, File        1267.tif
#  Vehicle            0
#  Airplane          15
#  Ship               0
#  Name: 1267, dtype: object, File        1268.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1268, dtype: object, File        1277.tif
#  Vehicle            0
#  Airplane           6
#  Ship               0
#  Name: 1277, dtype: object, File        1285.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1285, dtype: object, File        1293.tif
#  Vehicle            0
#  Airplane           4
#  Ship               0
#  Name: 1293, dtype: object, File        1296.tif
#  Vehicle            0
#  Airplane          12
#  Ship               0
#  Name: 1296, dtype: object, File        1302.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1302, dtype: object, File        1303.tif
#  Vehicle            0
#  Airplane           4
#  Ship               0
#  Name: 1303, dtype: object, File        1304.tif
#  Vehicle            0
#  Airplane           9
#  Ship               0
#  Name: 1304, dtype: object, File        1310.tif
#  Vehicle            0
#  Airplane           7
#  Ship               0
#  Name: 1310, dtype: object, File        1311.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1311, dtype: object, File        1315.tif
#  Vehicle            0
#  Airplane          12
#  Ship               0
#  Name: 1315, dtype: object, File        1323.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1323, dtype: object, File        1329.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1329, dtype: object, File        1331.tif
#  Vehicle            0
#  Airplane           3
#  Ship               0
#  Name: 1331, dtype: object, File        1334.tif
#  Vehicle            0
#  Airplane           3
#  Ship               0
#  Name: 1334, dtype: object, File        1337.tif
#  Vehicle            0
#  Airplane           4
#  Ship               0
#  Name: 1337, dtype: object, File        1339.tif
#  Vehicle            0
#  Airplane           6
#  Ship               0
#  Name: 1339, dtype: object, File        1345.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1345, dtype: object, File        1347.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1347, dtype: object, File        1349.tif
#  Vehicle            0
#  Airplane          74
#  Ship               0
#  Name: 1349, dtype: object, File        1354.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1354, dtype: object, File        1356.tif
#  Vehicle            0
#  Airplane           5
#  Ship               0
#  Name: 1356, dtype: object, File        1358.tif
#  Vehicle            0
#  Airplane           6
#  Ship               0
#  Name: 1358, dtype: object, File        1362.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1362, dtype: object, File        1365.tif
#  Vehicle            0
#  Airplane           5
#  Ship               0
#  Name: 1365, dtype: object, File        1366.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1366, dtype: object, File        1373.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1373, dtype: object, File        1374.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1374, dtype: object, File        1375.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1375, dtype: object, File        1395.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1395, dtype: object, File        1400.tif
#  Vehicle            0
#  Airplane          14
#  Ship               0
#  Name: 1400, dtype: object, File        1405.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1405, dtype: object, File        1415.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1415, dtype: object, File        1419.tif
#  Vehicle            0
#  Airplane          12
#  Ship               0
#  Name: 1419, dtype: object, File        1425.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1425, dtype: object, File        1433.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1433, dtype: object, File        1445.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1445, dtype: object, File        1448.tif
#  Vehicle            0
#  Airplane           3
#  Ship               0
#  Name: 1448, dtype: object, File        1449.tif
#  Vehicle            0
#  Airplane           3
#  Ship               0
#  Name: 1449, dtype: object, File        1455.tif
#  Vehicle            0
#  Airplane           3
#  Ship               0
#  Name: 1455, dtype: object, File        1456.tif
#  Vehicle            0
#  Airplane           7
#  Ship               0
#  Name: 1456, dtype: object, File        1468.tif
#  Vehicle            0
#  Airplane          12
#  Ship               0
#  Name: 1468, dtype: object, File        1470.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1470, dtype: object, File        1478.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1478, dtype: object, File        1481.tif
#  Vehicle            0
#  Airplane           6
#  Ship               0
#  Name: 1481, dtype: object, File        1484.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1484, dtype: object, File        1487.tif
#  Vehicle            0
#  Airplane           8
#  Ship               0
#  Name: 1487, dtype: object, File        1495.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1495, dtype: object, File        1503.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1503, dtype: object, File        1508.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1508, dtype: object, File        1510.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1510, dtype: object, File        1512.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1512, dtype: object, File        1513.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1513, dtype: object, File        1514.tif
#  Vehicle            0
#  Airplane           3
#  Ship               0
#  Name: 1514, dtype: object, File        1515.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1515, dtype: object, File        1524.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1524, dtype: object, File        1528.tif
#  Vehicle            0
#  Airplane           4
#  Ship               0
#  Name: 1528, dtype: object, File        1537.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1537, dtype: object, File        1538.tif
#  Vehicle            0
#  Airplane          18
#  Ship               0
#  Name: 1538, dtype: object, File        1542.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1542, dtype: object, File        1556.tif
#  Vehicle            0
#  Airplane           3
#  Ship               0
#  Name: 1556, dtype: object, File        1557.tif
#  Vehicle            0
#  Airplane           6
#  Ship               0
#  Name: 1557, dtype: object, File        1566.tif
#  Vehicle            0
#  Airplane           5
#  Ship               0
#  Name: 1566, dtype: object, File        1568.tif
#  Vehicle            0
#  Airplane           3
#  Ship               0
#  Name: 1568, dtype: object, File        1569.tif
#  Vehicle            0
#  Airplane           3
#  Ship               0
#  Name: 1569, dtype: object, File        1581.tif
#  Vehicle            0
#  Airplane           5
#  Ship               0
#  Name: 1581, dtype: object, File        1584.tif
#  Vehicle            0
#  Airplane           8
#  Ship               0
#  Name: 1584, dtype: object, File        1589.tif
#  Vehicle            0
#  Airplane           3
#  Ship               0
#  Name: 1589, dtype: object, File        1592.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1592, dtype: object, File        1597.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1597, dtype: object, File        1598.tif
#  Vehicle            0
#  Airplane           7
#  Ship               0
#  Name: 1598, dtype: object, File        1603.tif
#  Vehicle            0
#  Airplane           3
#  Ship               0
#  Name: 1603, dtype: object, File        1605.tif
#  Vehicle            0
#  Airplane           5
#  Ship               0
#  Name: 1605, dtype: object, File        1624.tif
#  Vehicle            0
#  Airplane           5
#  Ship               0
#  Name: 1624, dtype: object, File        1627.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1627, dtype: object, File        1636.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1636, dtype: object, File        1642.tif
#  Vehicle            0
#  Airplane           7
#  Ship               0
#  Name: 1642, dtype: object, File        1644.tif
#  Vehicle            0
#  Airplane           3
#  Ship               0
#  Name: 1644, dtype: object, File        1647.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1647, dtype: object, File        1653.tif
#  Vehicle            0
#  Airplane           4
#  Ship               0
#  Name: 1653, dtype: object, File        1661.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1661, dtype: object, File        1674.tif
#  Vehicle            0
#  Airplane          10
#  Ship               0
#  Name: 1674, dtype: object, File        1676.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1676, dtype: object, File        1679.tif
#  Vehicle            0
#  Airplane          19
#  Ship               0
#  Name: 1679, dtype: object, File        1680.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1680, dtype: object, File        1685.tif
#  Vehicle            0
#  Airplane           4
#  Ship               0
#  Name: 1685, dtype: object, File        1689.tif
#  Vehicle            0
#  Airplane           3
#  Ship               0
#  Name: 1689, dtype: object, File        1690.tif
#  Vehicle            0
#  Airplane           1
#  Ship               0
#  Name: 1690, dtype: object, File        1707.tif
#  Vehicle            0
#  Airplane           6
#  Ship               0
#  Name: 1707, dtype: object, File        1713.tif
#  Vehicle            0
#  Airplane           8
#  Ship               0
#  Name: 1713, dtype: object, File        1718.tif
#  Vehicle            0
#  Airplane           2
#  Ship               0
#  Name: 1718, dtype: object, File        1728.tif
#  Vehicle            0
#  Airplane           4
#  Ship               0
#  Name: 1728, dtype: object, File        1730.tif
#  Vehicle            0
#  Airplane           4
#  Ship               0
#  Name: 1730, dtype: object]

# %%
only_ship
# Out:
# [File        0.tif
#  Vehicle         0
#  Airplane        0
#  Ship            3
#  Name: 0, dtype: object, File        10.tif
#  Vehicle          0
#  Airplane         0
#  Ship             5
#  Name: 10, dtype: object, File        11.tif
#  Vehicle          0
#  Airplane         0
#  Ship             2
#  Name: 11, dtype: object, File        12.tif
#  Vehicle          0
#  Airplane         0
#  Ship            12
#  Name: 12, dtype: object, File        13.tif
#  Vehicle          0
#  Airplane         0
#  Ship             2
#  Name: 13, dtype: object, File        14.tif
#  Vehicle          0
#  Airplane         0
#  Ship             3
#  Name: 14, dtype: object, File        17.tif
#  Vehicle          0
#  Airplane         0
#  Ship             3
#  Name: 17, dtype: object, File        28.tif
#  Vehicle          0
#  Airplane         0
#  Ship            18
#  Name: 28, dtype: object, File        30.tif
#  Vehicle          0
#  Airplane         0
#  Ship             5
#  Name: 30, dtype: object, File        33.tif
#  Vehicle          0
#  Airplane         0
#  Ship             2
#  Name: 33, dtype: object, File        35.tif
#  Vehicle          0
#  Airplane         0
#  Ship             3
#  Name: 35, dtype: object, File        36.tif
#  Vehicle          0
#  Airplane         0
#  Ship             4
#  Name: 36, dtype: object, File        38.tif
#  Vehicle          0
#  Airplane         0
#  Ship             8
#  Name: 38, dtype: object, File        41.tif
#  Vehicle          0
#  Airplane         0
#  Ship            48
#  Name: 41, dtype: object, File        44.tif
#  Vehicle          0
#  Airplane         0
#  Ship             5
#  Name: 44, dtype: object, File        45.tif
#  Vehicle          0
#  Airplane         0
#  Ship            59
#  Name: 45, dtype: object, File        51.tif
#  Vehicle          0
#  Airplane         0
#  Ship             1
#  Name: 51, dtype: object, File        53.tif
#  Vehicle          0
#  Airplane         0
#  Ship            11
#  Name: 53, dtype: object, File        56.tif
#  Vehicle          0
#  Airplane         0
#  Ship             4
#  Name: 56, dtype: object, File        70.tif
#  Vehicle          0
#  Airplane         0
#  Ship             8
#  Name: 70, dtype: object, File        75.tif
#  Vehicle          0
#  Airplane         0
#  Ship            13
#  Name: 75, dtype: object, File        79.tif
#  Vehicle          0
#  Airplane         0
#  Ship             1
#  Name: 79, dtype: object, File        80.tif
#  Vehicle          0
#  Airplane         0
#  Ship             5
#  Name: 80, dtype: object, File        82.tif
#  Vehicle          0
#  Airplane         0
#  Ship            14
#  Name: 82, dtype: object, File        90.tif
#  Vehicle          0
#  Airplane         0
#  Ship             1
#  Name: 90, dtype: object, File        91.tif
#  Vehicle          0
#  Airplane         0
#  Ship             1
#  Name: 91, dtype: object, File        94.tif
#  Vehicle          0
#  Airplane         0
#  Ship             2
#  Name: 94, dtype: object, File        95.tif
#  Vehicle          0
#  Airplane         0
#  Ship             2
#  Name: 95, dtype: object, File        101.tif
#  Vehicle           0
#  Airplane          0
#  Ship             16
#  Name: 101, dtype: object, File        107.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 107, dtype: object, File        108.tif
#  Vehicle           0
#  Airplane          0
#  Ship              6
#  Name: 108, dtype: object, File        109.tif
#  Vehicle           0
#  Airplane          0
#  Ship              6
#  Name: 109, dtype: object, File        113.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 113, dtype: object, File        122.tif
#  Vehicle           0
#  Airplane          0
#  Ship             41
#  Name: 122, dtype: object, File        128.tif
#  Vehicle           0
#  Airplane          0
#  Ship             23
#  Name: 128, dtype: object, File        129.tif
#  Vehicle           0
#  Airplane          0
#  Ship             18
#  Name: 129, dtype: object, File        130.tif
#  Vehicle           0
#  Airplane          0
#  Ship             34
#  Name: 130, dtype: object, File        133.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 133, dtype: object, File        134.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 134, dtype: object, File        139.tif
#  Vehicle           0
#  Airplane          0
#  Ship              4
#  Name: 139, dtype: object, File        141.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 141, dtype: object, File        152.tif
#  Vehicle           0
#  Airplane          0
#  Ship              3
#  Name: 152, dtype: object, File        160.tif
#  Vehicle           0
#  Airplane          0
#  Ship              3
#  Name: 160, dtype: object, File        162.tif
#  Vehicle           0
#  Airplane          0
#  Ship              8
#  Name: 162, dtype: object, File        173.tif
#  Vehicle           0
#  Airplane          0
#  Ship             23
#  Name: 173, dtype: object, File        175.tif
#  Vehicle           0
#  Airplane          0
#  Ship             10
#  Name: 175, dtype: object, File        176.tif
#  Vehicle           0
#  Airplane          0
#  Ship             16
#  Name: 176, dtype: object, File        177.tif
#  Vehicle           0
#  Airplane          0
#  Ship             68
#  Name: 177, dtype: object, File        178.tif
#  Vehicle           0
#  Airplane          0
#  Ship              4
#  Name: 178, dtype: object, File        180.tif
#  Vehicle           0
#  Airplane          0
#  Ship             36
#  Name: 180, dtype: object, File        184.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 184, dtype: object, File        189.tif
#  Vehicle           0
#  Airplane          0
#  Ship             41
#  Name: 189, dtype: object, File        191.tif
#  Vehicle           0
#  Airplane          0
#  Ship              3
#  Name: 191, dtype: object, File        194.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 194, dtype: object, File        198.tif
#  Vehicle           0
#  Airplane          0
#  Ship              7
#  Name: 198, dtype: object, File        202.tif
#  Vehicle           0
#  Airplane          0
#  Ship             11
#  Name: 202, dtype: object, File        206.tif
#  Vehicle           0
#  Airplane          0
#  Ship              8
#  Name: 206, dtype: object, File        210.tif
#  Vehicle           0
#  Airplane          0
#  Ship              4
#  Name: 210, dtype: object, File        214.tif
#  Vehicle           0
#  Airplane          0
#  Ship              6
#  Name: 214, dtype: object, File        218.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 218, dtype: object, File        219.tif
#  Vehicle           0
#  Airplane          0
#  Ship              6
#  Name: 219, dtype: object, File        224.tif
#  Vehicle           0
#  Airplane          0
#  Ship              7
#  Name: 224, dtype: object, File        227.tif
#  Vehicle           0
#  Airplane          0
#  Ship             17
#  Name: 227, dtype: object, File        228.tif
#  Vehicle           0
#  Airplane          0
#  Ship             43
#  Name: 228, dtype: object, File        229.tif
#  Vehicle           0
#  Airplane          0
#  Ship              7
#  Name: 229, dtype: object, File        230.tif
#  Vehicle           0
#  Airplane          0
#  Ship            105
#  Name: 230, dtype: object, File        233.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 233, dtype: object, File        234.tif
#  Vehicle           0
#  Airplane          0
#  Ship              9
#  Name: 234, dtype: object, File        236.tif
#  Vehicle           0
#  Airplane          0
#  Ship              9
#  Name: 236, dtype: object, File        243.tif
#  Vehicle           0
#  Airplane          0
#  Ship              6
#  Name: 243, dtype: object, File        247.tif
#  Vehicle           0
#  Airplane          0
#  Ship              6
#  Name: 247, dtype: object, File        250.tif
#  Vehicle           0
#  Airplane          0
#  Ship             10
#  Name: 250, dtype: object, File        256.tif
#  Vehicle           0
#  Airplane          0
#  Ship              5
#  Name: 256, dtype: object, File        260.tif
#  Vehicle           0
#  Airplane          0
#  Ship              4
#  Name: 260, dtype: object, File        261.tif
#  Vehicle           0
#  Airplane          0
#  Ship              5
#  Name: 261, dtype: object, File        263.tif
#  Vehicle           0
#  Airplane          0
#  Ship             28
#  Name: 263, dtype: object, File        267.tif
#  Vehicle           0
#  Airplane          0
#  Ship              5
#  Name: 267, dtype: object, File        270.tif
#  Vehicle           0
#  Airplane          0
#  Ship              6
#  Name: 270, dtype: object, File        278.tif
#  Vehicle           0
#  Airplane          0
#  Ship            184
#  Name: 278, dtype: object, File        292.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 292, dtype: object, File        304.tif
#  Vehicle           0
#  Airplane          0
#  Ship              8
#  Name: 304, dtype: object, File        305.tif
#  Vehicle           0
#  Airplane          0
#  Ship              4
#  Name: 305, dtype: object, File        308.tif
#  Vehicle           0
#  Airplane          0
#  Ship              6
#  Name: 308, dtype: object, File        312.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 312, dtype: object, File        314.tif
#  Vehicle           0
#  Airplane          0
#  Ship             15
#  Name: 314, dtype: object, File        315.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 315, dtype: object, File        316.tif
#  Vehicle           0
#  Airplane          0
#  Ship              7
#  Name: 316, dtype: object, File        317.tif
#  Vehicle           0
#  Airplane          0
#  Ship              3
#  Name: 317, dtype: object, File        321.tif
#  Vehicle           0
#  Airplane          0
#  Ship              4
#  Name: 321, dtype: object, File        327.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 327, dtype: object, File        335.tif
#  Vehicle           0
#  Airplane          0
#  Ship              5
#  Name: 335, dtype: object, File        336.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 336, dtype: object, File        348.tif
#  Vehicle           0
#  Airplane          0
#  Ship             21
#  Name: 348, dtype: object, File        349.tif
#  Vehicle           0
#  Airplane          0
#  Ship              8
#  Name: 349, dtype: object, File        351.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 351, dtype: object, File        354.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 354, dtype: object, File        360.tif
#  Vehicle           0
#  Airplane          0
#  Ship             12
#  Name: 360, dtype: object, File        364.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 364, dtype: object, File        367.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 367, dtype: object, File        375.tif
#  Vehicle           0
#  Airplane          0
#  Ship              5
#  Name: 375, dtype: object, File        379.tif
#  Vehicle           0
#  Airplane          0
#  Ship              4
#  Name: 379, dtype: object, File        380.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 380, dtype: object, File        382.tif
#  Vehicle           0
#  Airplane          0
#  Ship             10
#  Name: 382, dtype: object, File        386.tif
#  Vehicle           0
#  Airplane          0
#  Ship              6
#  Name: 386, dtype: object, File        395.tif
#  Vehicle           0
#  Airplane          0
#  Ship              5
#  Name: 395, dtype: object, File        396.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 396, dtype: object, File        400.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 400, dtype: object, File        401.tif
#  Vehicle           0
#  Airplane          0
#  Ship             12
#  Name: 401, dtype: object, File        404.tif
#  Vehicle           0
#  Airplane          0
#  Ship              7
#  Name: 404, dtype: object, File        405.tif
#  Vehicle           0
#  Airplane          0
#  Ship             11
#  Name: 405, dtype: object, File        407.tif
#  Vehicle           0
#  Airplane          0
#  Ship             12
#  Name: 407, dtype: object, File        409.tif
#  Vehicle           0
#  Airplane          0
#  Ship              6
#  Name: 409, dtype: object, File        414.tif
#  Vehicle           0
#  Airplane          0
#  Ship              4
#  Name: 414, dtype: object, File        420.tif
#  Vehicle           0
#  Airplane          0
#  Ship              9
#  Name: 420, dtype: object, File        421.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 421, dtype: object, File        422.tif
#  Vehicle           0
#  Airplane          0
#  Ship             11
#  Name: 422, dtype: object, File        427.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 427, dtype: object, File        430.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 430, dtype: object, File        435.tif
#  Vehicle           0
#  Airplane          0
#  Ship              8
#  Name: 435, dtype: object, File        438.tif
#  Vehicle           0
#  Airplane          0
#  Ship             19
#  Name: 438, dtype: object, File        442.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 442, dtype: object, File        443.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 443, dtype: object, File        444.tif
#  Vehicle           0
#  Airplane          0
#  Ship              8
#  Name: 444, dtype: object, File        445.tif
#  Vehicle           0
#  Airplane          0
#  Ship             23
#  Name: 445, dtype: object, File        450.tif
#  Vehicle           0
#  Airplane          0
#  Ship             23
#  Name: 450, dtype: object, File        455.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 455, dtype: object, File        456.tif
#  Vehicle           0
#  Airplane          0
#  Ship              3
#  Name: 456, dtype: object, File        462.tif
#  Vehicle           0
#  Airplane          0
#  Ship              7
#  Name: 462, dtype: object, File        469.tif
#  Vehicle           0
#  Airplane          0
#  Ship             64
#  Name: 469, dtype: object, File        471.tif
#  Vehicle           0
#  Airplane          0
#  Ship              6
#  Name: 471, dtype: object, File        474.tif
#  Vehicle           0
#  Airplane          0
#  Ship              9
#  Name: 474, dtype: object, File        475.tif
#  Vehicle           0
#  Airplane          0
#  Ship             27
#  Name: 475, dtype: object, File        476.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 476, dtype: object, File        477.tif
#  Vehicle           0
#  Airplane          0
#  Ship              6
#  Name: 477, dtype: object, File        481.tif
#  Vehicle           0
#  Airplane          0
#  Ship              9
#  Name: 481, dtype: object, File        483.tif
#  Vehicle           0
#  Airplane          0
#  Ship             33
#  Name: 483, dtype: object, File        485.tif
#  Vehicle           0
#  Airplane          0
#  Ship             22
#  Name: 485, dtype: object, File        486.tif
#  Vehicle           0
#  Airplane          0
#  Ship            106
#  Name: 486, dtype: object, File        489.tif
#  Vehicle           0
#  Airplane          0
#  Ship              4
#  Name: 489, dtype: object, File        498.tif
#  Vehicle           0
#  Airplane          0
#  Ship              5
#  Name: 498, dtype: object, File        505.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 505, dtype: object, File        506.tif
#  Vehicle           0
#  Airplane          0
#  Ship              5
#  Name: 506, dtype: object, File        510.tif
#  Vehicle           0
#  Airplane          0
#  Ship             35
#  Name: 510, dtype: object, File        513.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 513, dtype: object, File        514.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 514, dtype: object, File        517.tif
#  Vehicle           0
#  Airplane          0
#  Ship              4
#  Name: 517, dtype: object, File        520.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 520, dtype: object, File        527.tif
#  Vehicle           0
#  Airplane          0
#  Ship              5
#  Name: 527, dtype: object, File        532.tif
#  Vehicle           0
#  Airplane          0
#  Ship              7
#  Name: 532, dtype: object, File        533.tif
#  Vehicle           0
#  Airplane          0
#  Ship              9
#  Name: 533, dtype: object, File        534.tif
#  Vehicle           0
#  Airplane          0
#  Ship              4
#  Name: 534, dtype: object, File        535.tif
#  Vehicle           0
#  Airplane          0
#  Ship              8
#  Name: 535, dtype: object, File        536.tif
#  Vehicle           0
#  Airplane          0
#  Ship              5
#  Name: 536, dtype: object, File        540.tif
#  Vehicle           0
#  Airplane          0
#  Ship              3
#  Name: 540, dtype: object, File        546.tif
#  Vehicle           0
#  Airplane          0
#  Ship              5
#  Name: 546, dtype: object, File        547.tif
#  Vehicle           0
#  Airplane          0
#  Ship             27
#  Name: 547, dtype: object, File        551.tif
#  Vehicle           0
#  Airplane          0
#  Ship              7
#  Name: 551, dtype: object, File        554.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 554, dtype: object, File        563.tif
#  Vehicle           0
#  Airplane          0
#  Ship             80
#  Name: 563, dtype: object, File        572.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 572, dtype: object, File        576.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 576, dtype: object, File        578.tif
#  Vehicle           0
#  Airplane          0
#  Ship              3
#  Name: 578, dtype: object, File        583.tif
#  Vehicle           0
#  Airplane          0
#  Ship             80
#  Name: 583, dtype: object, File        588.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 588, dtype: object, File        592.tif
#  Vehicle           0
#  Airplane          0
#  Ship              3
#  Name: 592, dtype: object, File        593.tif
#  Vehicle           0
#  Airplane          0
#  Ship             91
#  Name: 593, dtype: object, File        597.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 597, dtype: object, File        610.tif
#  Vehicle           0
#  Airplane          0
#  Ship             14
#  Name: 610, dtype: object, File        613.tif
#  Vehicle           0
#  Airplane          0
#  Ship             11
#  Name: 613, dtype: object, File        614.tif
#  Vehicle           0
#  Airplane          0
#  Ship             70
#  Name: 614, dtype: object, File        615.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 615, dtype: object, File        619.tif
#  Vehicle           0
#  Airplane          0
#  Ship              3
#  Name: 619, dtype: object, File        625.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 625, dtype: object, File        626.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 626, dtype: object, File        633.tif
#  Vehicle           0
#  Airplane          0
#  Ship              4
#  Name: 633, dtype: object, File        637.tif
#  Vehicle           0
#  Airplane          0
#  Ship              7
#  Name: 637, dtype: object, File        641.tif
#  Vehicle           0
#  Airplane          0
#  Ship             16
#  Name: 641, dtype: object, File        643.tif
#  Vehicle           0
#  Airplane          0
#  Ship              7
#  Name: 643, dtype: object, File        647.tif
#  Vehicle           0
#  Airplane          0
#  Ship             17
#  Name: 647, dtype: object, File        648.tif
#  Vehicle           0
#  Airplane          0
#  Ship             16
#  Name: 648, dtype: object, File        655.tif
#  Vehicle           0
#  Airplane          0
#  Ship              4
#  Name: 655, dtype: object, File        657.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 657, dtype: object, File        666.tif
#  Vehicle           0
#  Airplane          0
#  Ship             25
#  Name: 666, dtype: object, File        671.tif
#  Vehicle           0
#  Airplane          0
#  Ship             17
#  Name: 671, dtype: object, File        672.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 672, dtype: object, File        673.tif
#  Vehicle           0
#  Airplane          0
#  Ship            102
#  Name: 673, dtype: object, File        675.tif
#  Vehicle           0
#  Airplane          0
#  Ship             31
#  Name: 675, dtype: object, File        677.tif
#  Vehicle           0
#  Airplane          0
#  Ship              3
#  Name: 677, dtype: object, File        680.tif
#  Vehicle           0
#  Airplane          0
#  Ship             27
#  Name: 680, dtype: object, File        682.tif
#  Vehicle           0
#  Airplane          0
#  Ship              3
#  Name: 682, dtype: object, File        690.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 690, dtype: object, File        693.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 693, dtype: object, File        697.tif
#  Vehicle           0
#  Airplane          0
#  Ship             29
#  Name: 697, dtype: object, File        701.tif
#  Vehicle           0
#  Airplane          0
#  Ship             18
#  Name: 701, dtype: object, File        708.tif
#  Vehicle           0
#  Airplane          0
#  Ship             32
#  Name: 708, dtype: object, File        718.tif
#  Vehicle           0
#  Airplane          0
#  Ship              4
#  Name: 718, dtype: object, File        720.tif
#  Vehicle           0
#  Airplane          0
#  Ship              4
#  Name: 720, dtype: object, File        724.tif
#  Vehicle           0
#  Airplane          0
#  Ship              3
#  Name: 724, dtype: object, File        727.tif
#  Vehicle           0
#  Airplane          0
#  Ship              4
#  Name: 727, dtype: object, File        744.tif
#  Vehicle           0
#  Airplane          0
#  Ship              5
#  Name: 744, dtype: object, File        745.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 745, dtype: object, File        748.tif
#  Vehicle           0
#  Airplane          0
#  Ship              4
#  Name: 748, dtype: object, File        754.tif
#  Vehicle           0
#  Airplane          0
#  Ship             12
#  Name: 754, dtype: object, File        761.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 761, dtype: object, File        762.tif
#  Vehicle           0
#  Airplane          0
#  Ship             16
#  Name: 762, dtype: object, File        764.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 764, dtype: object, File        767.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 767, dtype: object, File        772.tif
#  Vehicle           0
#  Airplane          0
#  Ship              7
#  Name: 772, dtype: object, File        774.tif
#  Vehicle           0
#  Airplane          0
#  Ship             15
#  Name: 774, dtype: object, File        785.tif
#  Vehicle           0
#  Airplane          0
#  Ship              3
#  Name: 785, dtype: object, File        786.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 786, dtype: object, File        798.tif
#  Vehicle           0
#  Airplane          0
#  Ship              9
#  Name: 798, dtype: object, File        799.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 799, dtype: object, File        803.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 803, dtype: object, File        808.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 808, dtype: object, File        810.tif
#  Vehicle           0
#  Airplane          0
#  Ship             20
#  Name: 810, dtype: object, File        812.tif
#  Vehicle           0
#  Airplane          0
#  Ship              3
#  Name: 812, dtype: object, File        814.tif
#  Vehicle           0
#  Airplane          0
#  Ship              3
#  Name: 814, dtype: object, File        816.tif
#  Vehicle           0
#  Airplane          0
#  Ship              9
#  Name: 816, dtype: object, File        823.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 823, dtype: object, File        824.tif
#  Vehicle           0
#  Airplane          0
#  Ship              5
#  Name: 824, dtype: object, File        827.tif
#  Vehicle           0
#  Airplane          0
#  Ship              3
#  Name: 827, dtype: object, File        832.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 832, dtype: object, File        834.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 834, dtype: object, File        841.tif
#  Vehicle           0
#  Airplane          0
#  Ship             24
#  Name: 841, dtype: object, File        844.tif
#  Vehicle           0
#  Airplane          0
#  Ship             49
#  Name: 844, dtype: object, File        848.tif
#  Vehicle           0
#  Airplane          0
#  Ship             11
#  Name: 848, dtype: object, File        858.tif
#  Vehicle           0
#  Airplane          0
#  Ship             30
#  Name: 858, dtype: object, File        859.tif
#  Vehicle           0
#  Airplane          0
#  Ship             11
#  Name: 859, dtype: object, File        867.tif
#  Vehicle           0
#  Airplane          0
#  Ship              4
#  Name: 867, dtype: object, File        868.tif
#  Vehicle           0
#  Airplane          0
#  Ship              4
#  Name: 868, dtype: object, File        871.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 871, dtype: object, File        873.tif
#  Vehicle           0
#  Airplane          0
#  Ship             27
#  Name: 873, dtype: object, File        879.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 879, dtype: object, File        881.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 881, dtype: object, File        884.tif
#  Vehicle           0
#  Airplane          0
#  Ship              5
#  Name: 884, dtype: object, File        889.tif
#  Vehicle           0
#  Airplane          0
#  Ship              7
#  Name: 889, dtype: object, File        892.tif
#  Vehicle           0
#  Airplane          0
#  Ship              5
#  Name: 892, dtype: object, File        893.tif
#  Vehicle           0
#  Airplane          0
#  Ship              3
#  Name: 893, dtype: object, File        896.tif
#  Vehicle           0
#  Airplane          0
#  Ship             19
#  Name: 896, dtype: object, File        900.tif
#  Vehicle           0
#  Airplane          0
#  Ship             56
#  Name: 900, dtype: object, File        902.tif
#  Vehicle           0
#  Airplane          0
#  Ship             21
#  Name: 902, dtype: object, File        903.tif
#  Vehicle           0
#  Airplane          0
#  Ship              7
#  Name: 903, dtype: object, File        905.tif
#  Vehicle           0
#  Airplane          0
#  Ship              7
#  Name: 905, dtype: object, File        908.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 908, dtype: object, File        911.tif
#  Vehicle           0
#  Airplane          0
#  Ship              6
#  Name: 911, dtype: object, File        913.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 913, dtype: object, File        921.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 921, dtype: object, File        925.tif
#  Vehicle           0
#  Airplane          0
#  Ship             45
#  Name: 925, dtype: object, File        927.tif
#  Vehicle           0
#  Airplane          0
#  Ship              3
#  Name: 927, dtype: object, File        930.tif
#  Vehicle           0
#  Airplane          0
#  Ship              5
#  Name: 930, dtype: object, File        935.tif
#  Vehicle           0
#  Airplane          0
#  Ship             66
#  Name: 935, dtype: object, File        937.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 937, dtype: object, File        940.tif
#  Vehicle           0
#  Airplane          0
#  Ship              3
#  Name: 940, dtype: object, File        943.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 943, dtype: object, File        950.tif
#  Vehicle           0
#  Airplane          0
#  Ship              6
#  Name: 950, dtype: object, File        951.tif
#  Vehicle           0
#  Airplane          0
#  Ship             18
#  Name: 951, dtype: object, File        953.tif
#  Vehicle           0
#  Airplane          0
#  Ship             13
#  Name: 953, dtype: object, File        954.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 954, dtype: object, File        958.tif
#  Vehicle           0
#  Airplane          0
#  Ship             30
#  Name: 958, dtype: object, File        961.tif
#  Vehicle           0
#  Airplane          0
#  Ship              9
#  Name: 961, dtype: object, File        963.tif
#  Vehicle           0
#  Airplane          0
#  Ship             26
#  Name: 963, dtype: object, File        968.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 968, dtype: object, File        973.tif
#  Vehicle           0
#  Airplane          0
#  Ship              7
#  Name: 973, dtype: object, File        978.tif
#  Vehicle           0
#  Airplane          0
#  Ship             15
#  Name: 978, dtype: object, File        980.tif
#  Vehicle           0
#  Airplane          0
#  Ship             50
#  Name: 980, dtype: object, File        981.tif
#  Vehicle           0
#  Airplane          0
#  Ship              1
#  Name: 981, dtype: object, File        984.tif
#  Vehicle           0
#  Airplane          0
#  Ship             40
#  Name: 984, dtype: object, File        985.tif
#  Vehicle           0
#  Airplane          0
#  Ship              3
#  Name: 985, dtype: object, File        987.tif
#  Vehicle           0
#  Airplane          0
#  Ship              4
#  Name: 987, dtype: object, File        989.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 989, dtype: object, File        998.tif
#  Vehicle           0
#  Airplane          0
#  Ship              2
#  Name: 998, dtype: object, File        1006.tif
#  Vehicle            0
#  Airplane           0
#  Ship               3
#  Name: 1006, dtype: object, File        1014.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1014, dtype: object, File        1020.tif
#  Vehicle            0
#  Airplane           0
#  Ship              50
#  Name: 1020, dtype: object, File        1021.tif
#  Vehicle            0
#  Airplane           0
#  Ship               1
#  Name: 1021, dtype: object, File        1022.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1022, dtype: object, File        1024.tif
#  Vehicle            0
#  Airplane           0
#  Ship             187
#  Name: 1024, dtype: object, File        1025.tif
#  Vehicle            0
#  Airplane           0
#  Ship               1
#  Name: 1025, dtype: object, File        1027.tif
#  Vehicle            0
#  Airplane           0
#  Ship              39
#  Name: 1027, dtype: object, File        1035.tif
#  Vehicle            0
#  Airplane           0
#  Ship               8
#  Name: 1035, dtype: object, File        1038.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1038, dtype: object, File        1039.tif
#  Vehicle            0
#  Airplane           0
#  Ship              60
#  Name: 1039, dtype: object, File        1045.tif
#  Vehicle            0
#  Airplane           0
#  Ship               1
#  Name: 1045, dtype: object, File        1046.tif
#  Vehicle            0
#  Airplane           0
#  Ship             151
#  Name: 1046, dtype: object, File        1050.tif
#  Vehicle            0
#  Airplane           0
#  Ship               6
#  Name: 1050, dtype: object, File        1053.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1053, dtype: object, File        1055.tif
#  Vehicle            0
#  Airplane           0
#  Ship              48
#  Name: 1055, dtype: object, File        1058.tif
#  Vehicle            0
#  Airplane           0
#  Ship              11
#  Name: 1058, dtype: object, File        1060.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1060, dtype: object, File        1061.tif
#  Vehicle            0
#  Airplane           0
#  Ship               3
#  Name: 1061, dtype: object, File        1063.tif
#  Vehicle            0
#  Airplane           0
#  Ship               5
#  Name: 1063, dtype: object, File        1066.tif
#  Vehicle            0
#  Airplane           0
#  Ship              27
#  Name: 1066, dtype: object, File        1067.tif
#  Vehicle            0
#  Airplane           0
#  Ship               7
#  Name: 1067, dtype: object, File        1074.tif
#  Vehicle            0
#  Airplane           0
#  Ship               4
#  Name: 1074, dtype: object, File        1075.tif
#  Vehicle            0
#  Airplane           0
#  Ship               9
#  Name: 1075, dtype: object, File        1081.tif
#  Vehicle            0
#  Airplane           0
#  Ship               9
#  Name: 1081, dtype: object, File        1086.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1086, dtype: object, File        1089.tif
#  Vehicle            0
#  Airplane           0
#  Ship               3
#  Name: 1089, dtype: object, File        1092.tif
#  Vehicle            0
#  Airplane           0
#  Ship               7
#  Name: 1092, dtype: object, File        1097.tif
#  Vehicle            0
#  Airplane           0
#  Ship              27
#  Name: 1097, dtype: object, File        1102.tif
#  Vehicle            0
#  Airplane           0
#  Ship              10
#  Name: 1102, dtype: object, File        1103.tif
#  Vehicle            0
#  Airplane           0
#  Ship               3
#  Name: 1103, dtype: object, File        1106.tif
#  Vehicle            0
#  Airplane           0
#  Ship               6
#  Name: 1106, dtype: object, File        1108.tif
#  Vehicle            0
#  Airplane           0
#  Ship               4
#  Name: 1108, dtype: object, File        1110.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1110, dtype: object, File        1114.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1114, dtype: object, File        1117.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1117, dtype: object, File        1122.tif
#  Vehicle            0
#  Airplane           0
#  Ship              18
#  Name: 1122, dtype: object, File        1127.tif
#  Vehicle            0
#  Airplane           0
#  Ship               1
#  Name: 1127, dtype: object, File        1129.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1129, dtype: object, File        1130.tif
#  Vehicle            0
#  Airplane           0
#  Ship              15
#  Name: 1130, dtype: object, File        1138.tif
#  Vehicle            0
#  Airplane           0
#  Ship               3
#  Name: 1138, dtype: object, File        1139.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1139, dtype: object, File        1141.tif
#  Vehicle            0
#  Airplane           0
#  Ship              13
#  Name: 1141, dtype: object, File        1142.tif
#  Vehicle            0
#  Airplane           0
#  Ship               5
#  Name: 1142, dtype: object, File        1145.tif
#  Vehicle            0
#  Airplane           0
#  Ship              11
#  Name: 1145, dtype: object, File        1151.tif
#  Vehicle            0
#  Airplane           0
#  Ship               8
#  Name: 1151, dtype: object, File        1158.tif
#  Vehicle            0
#  Airplane           0
#  Ship              11
#  Name: 1158, dtype: object, File        1159.tif
#  Vehicle            0
#  Airplane           0
#  Ship               1
#  Name: 1159, dtype: object, File        1173.tif
#  Vehicle            0
#  Airplane           0
#  Ship               7
#  Name: 1173, dtype: object, File        1180.tif
#  Vehicle            0
#  Airplane           0
#  Ship               5
#  Name: 1180, dtype: object, File        1186.tif
#  Vehicle            0
#  Airplane           0
#  Ship              11
#  Name: 1186, dtype: object, File        1187.tif
#  Vehicle            0
#  Airplane           0
#  Ship               6
#  Name: 1187, dtype: object, File        1189.tif
#  Vehicle            0
#  Airplane           0
#  Ship              72
#  Name: 1189, dtype: object, File        1190.tif
#  Vehicle            0
#  Airplane           0
#  Ship               9
#  Name: 1190, dtype: object, File        1194.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1194, dtype: object, File        1198.tif
#  Vehicle            0
#  Airplane           0
#  Ship              17
#  Name: 1198, dtype: object, File        1199.tif
#  Vehicle            0
#  Airplane           0
#  Ship              21
#  Name: 1199, dtype: object, File        1201.tif
#  Vehicle            0
#  Airplane           0
#  Ship               3
#  Name: 1201, dtype: object, File        1202.tif
#  Vehicle            0
#  Airplane           0
#  Ship               9
#  Name: 1202, dtype: object, File        1203.tif
#  Vehicle            0
#  Airplane           0
#  Ship              59
#  Name: 1203, dtype: object, File        1206.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1206, dtype: object, File        1207.tif
#  Vehicle            0
#  Airplane           0
#  Ship               5
#  Name: 1207, dtype: object, File        1212.tif
#  Vehicle            0
#  Airplane           0
#  Ship              27
#  Name: 1212, dtype: object, File        1214.tif
#  Vehicle            0
#  Airplane           0
#  Ship               6
#  Name: 1214, dtype: object, File        1219.tif
#  Vehicle            0
#  Airplane           0
#  Ship              12
#  Name: 1219, dtype: object, File        1220.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1220, dtype: object, File        1225.tif
#  Vehicle            0
#  Airplane           0
#  Ship               1
#  Name: 1225, dtype: object, File        1228.tif
#  Vehicle            0
#  Airplane           0
#  Ship               1
#  Name: 1228, dtype: object, File        1232.tif
#  Vehicle            0
#  Airplane           0
#  Ship              54
#  Name: 1232, dtype: object, File        1236.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1236, dtype: object, File        1239.tif
#  Vehicle            0
#  Airplane           0
#  Ship              30
#  Name: 1239, dtype: object, File        1242.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1242, dtype: object, File        1247.tif
#  Vehicle            0
#  Airplane           0
#  Ship               7
#  Name: 1247, dtype: object, File        1251.tif
#  Vehicle            0
#  Airplane           0
#  Ship               4
#  Name: 1251, dtype: object, File        1252.tif
#  Vehicle            0
#  Airplane           0
#  Ship             112
#  Name: 1252, dtype: object, File        1269.tif
#  Vehicle            0
#  Airplane           0
#  Ship               9
#  Name: 1269, dtype: object, File        1270.tif
#  Vehicle            0
#  Airplane           0
#  Ship             161
#  Name: 1270, dtype: object, File        1271.tif
#  Vehicle            0
#  Airplane           0
#  Ship               6
#  Name: 1271, dtype: object, File        1272.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1272, dtype: object, File        1273.tif
#  Vehicle            0
#  Airplane           0
#  Ship               7
#  Name: 1273, dtype: object, File        1275.tif
#  Vehicle            0
#  Airplane           0
#  Ship              12
#  Name: 1275, dtype: object, File        1276.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1276, dtype: object, File        1280.tif
#  Vehicle            0
#  Airplane           0
#  Ship              11
#  Name: 1280, dtype: object, File        1283.tif
#  Vehicle            0
#  Airplane           0
#  Ship               1
#  Name: 1283, dtype: object, File        1286.tif
#  Vehicle            0
#  Airplane           0
#  Ship              12
#  Name: 1286, dtype: object, File        1287.tif
#  Vehicle            0
#  Airplane           0
#  Ship               1
#  Name: 1287, dtype: object, File        1288.tif
#  Vehicle            0
#  Airplane           0
#  Ship               5
#  Name: 1288, dtype: object, File        1291.tif
#  Vehicle            0
#  Airplane           0
#  Ship              21
#  Name: 1291, dtype: object, File        1295.tif
#  Vehicle            0
#  Airplane           0
#  Ship              14
#  Name: 1295, dtype: object, File        1298.tif
#  Vehicle            0
#  Airplane           0
#  Ship              10
#  Name: 1298, dtype: object, File        1305.tif
#  Vehicle            0
#  Airplane           0
#  Ship               5
#  Name: 1305, dtype: object, File        1307.tif
#  Vehicle            0
#  Airplane           0
#  Ship               5
#  Name: 1307, dtype: object, File        1308.tif
#  Vehicle            0
#  Airplane           0
#  Ship               4
#  Name: 1308, dtype: object, File        1312.tif
#  Vehicle            0
#  Airplane           0
#  Ship               3
#  Name: 1312, dtype: object, File        1313.tif
#  Vehicle            0
#  Airplane           0
#  Ship               1
#  Name: 1313, dtype: object, File        1320.tif
#  Vehicle            0
#  Airplane           0
#  Ship               7
#  Name: 1320, dtype: object, File        1321.tif
#  Vehicle            0
#  Airplane           0
#  Ship               1
#  Name: 1321, dtype: object, File        1328.tif
#  Vehicle            0
#  Airplane           0
#  Ship               1
#  Name: 1328, dtype: object, File        1333.tif
#  Vehicle            0
#  Airplane           0
#  Ship              18
#  Name: 1333, dtype: object, File        1341.tif
#  Vehicle            0
#  Airplane           0
#  Ship               3
#  Name: 1341, dtype: object, File        1343.tif
#  Vehicle            0
#  Airplane           0
#  Ship               9
#  Name: 1343, dtype: object, File        1346.tif
#  Vehicle            0
#  Airplane           0
#  Ship              12
#  Name: 1346, dtype: object, File        1360.tif
#  Vehicle            0
#  Airplane           0
#  Ship               3
#  Name: 1360, dtype: object, File        1363.tif
#  Vehicle            0
#  Airplane           0
#  Ship              10
#  Name: 1363, dtype: object, File        1367.tif
#  Vehicle            0
#  Airplane           0
#  Ship              12
#  Name: 1367, dtype: object, File        1372.tif
#  Vehicle            0
#  Airplane           0
#  Ship               3
#  Name: 1372, dtype: object, File        1379.tif
#  Vehicle            0
#  Airplane           0
#  Ship               4
#  Name: 1379, dtype: object, File        1383.tif
#  Vehicle            0
#  Airplane           0
#  Ship               1
#  Name: 1383, dtype: object, File        1389.tif
#  Vehicle            0
#  Airplane           0
#  Ship               1
#  Name: 1389, dtype: object, File        1390.tif
#  Vehicle            0
#  Airplane           0
#  Ship              17
#  Name: 1390, dtype: object, File        1391.tif
#  Vehicle            0
#  Airplane           0
#  Ship               6
#  Name: 1391, dtype: object, File        1398.tif
#  Vehicle            0
#  Airplane           0
#  Ship               3
#  Name: 1398, dtype: object, File        1402.tif
#  Vehicle            0
#  Airplane           0
#  Ship              26
#  Name: 1402, dtype: object, File        1408.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1408, dtype: object, File        1412.tif
#  Vehicle            0
#  Airplane           0
#  Ship             102
#  Name: 1412, dtype: object, File        1414.tif
#  Vehicle            0
#  Airplane           0
#  Ship               1
#  Name: 1414, dtype: object, File        1417.tif
#  Vehicle            0
#  Airplane           0
#  Ship               3
#  Name: 1417, dtype: object, File        1418.tif
#  Vehicle            0
#  Airplane           0
#  Ship               4
#  Name: 1418, dtype: object, File        1431.tif
#  Vehicle            0
#  Airplane           0
#  Ship               4
#  Name: 1431, dtype: object, File        1434.tif
#  Vehicle            0
#  Airplane           0
#  Ship              35
#  Name: 1434, dtype: object, File        1438.tif
#  Vehicle            0
#  Airplane           0
#  Ship               1
#  Name: 1438, dtype: object, File        1439.tif
#  Vehicle            0
#  Airplane           0
#  Ship              26
#  Name: 1439, dtype: object, File        1442.tif
#  Vehicle            0
#  Airplane           0
#  Ship               8
#  Name: 1442, dtype: object, File        1444.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1444, dtype: object, File        1446.tif
#  Vehicle            0
#  Airplane           0
#  Ship               9
#  Name: 1446, dtype: object, File        1451.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1451, dtype: object, File        1457.tif
#  Vehicle            0
#  Airplane           0
#  Ship              10
#  Name: 1457, dtype: object, File        1460.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1460, dtype: object, File        1467.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1467, dtype: object, File        1469.tif
#  Vehicle            0
#  Airplane           0
#  Ship               3
#  Name: 1469, dtype: object, File        1471.tif
#  Vehicle            0
#  Airplane           0
#  Ship               6
#  Name: 1471, dtype: object, File        1473.tif
#  Vehicle            0
#  Airplane           0
#  Ship               9
#  Name: 1473, dtype: object, File        1479.tif
#  Vehicle            0
#  Airplane           0
#  Ship               5
#  Name: 1479, dtype: object, File        1482.tif
#  Vehicle            0
#  Airplane           0
#  Ship              16
#  Name: 1482, dtype: object, File        1489.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1489, dtype: object, File        1493.tif
#  Vehicle            0
#  Airplane           0
#  Ship              13
#  Name: 1493, dtype: object, File        1494.tif
#  Vehicle            0
#  Airplane           0
#  Ship               6
#  Name: 1494, dtype: object, File        1496.tif
#  Vehicle            0
#  Airplane           0
#  Ship               3
#  Name: 1496, dtype: object, File        1501.tif
#  Vehicle            0
#  Airplane           0
#  Ship               1
#  Name: 1501, dtype: object, File        1502.tif
#  Vehicle            0
#  Airplane           0
#  Ship               3
#  Name: 1502, dtype: object, File        1505.tif
#  Vehicle            0
#  Airplane           0
#  Ship               1
#  Name: 1505, dtype: object, File        1516.tif
#  Vehicle            0
#  Airplane           0
#  Ship               3
#  Name: 1516, dtype: object, File        1523.tif
#  Vehicle            0
#  Airplane           0
#  Ship               4
#  Name: 1523, dtype: object, File        1526.tif
#  Vehicle            0
#  Airplane           0
#  Ship               7
#  Name: 1526, dtype: object, File        1529.tif
#  Vehicle            0
#  Airplane           0
#  Ship              32
#  Name: 1529, dtype: object, File        1531.tif
#  Vehicle            0
#  Airplane           0
#  Ship               1
#  Name: 1531, dtype: object, File        1547.tif
#  Vehicle            0
#  Airplane           0
#  Ship              52
#  Name: 1547, dtype: object, File        1550.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1550, dtype: object, File        1552.tif
#  Vehicle            0
#  Airplane           0
#  Ship               3
#  Name: 1552, dtype: object, File        1554.tif
#  Vehicle            0
#  Airplane           0
#  Ship              14
#  Name: 1554, dtype: object, File        1558.tif
#  Vehicle            0
#  Airplane           0
#  Ship               7
#  Name: 1558, dtype: object, File        1561.tif
#  Vehicle            0
#  Airplane           0
#  Ship              12
#  Name: 1561, dtype: object, File        1570.tif
#  Vehicle            0
#  Airplane           0
#  Ship               5
#  Name: 1570, dtype: object, File        1573.tif
#  Vehicle            0
#  Airplane           0
#  Ship               3
#  Name: 1573, dtype: object, File        1575.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1575, dtype: object, File        1578.tif
#  Vehicle            0
#  Airplane           0
#  Ship              17
#  Name: 1578, dtype: object, File        1579.tif
#  Vehicle            0
#  Airplane           0
#  Ship               1
#  Name: 1579, dtype: object, File        1582.tif
#  Vehicle            0
#  Airplane           0
#  Ship              17
#  Name: 1582, dtype: object, File        1585.tif
#  Vehicle            0
#  Airplane           0
#  Ship              49
#  Name: 1585, dtype: object, File        1591.tif
#  Vehicle            0
#  Airplane           0
#  Ship               5
#  Name: 1591, dtype: object, File        1594.tif
#  Vehicle            0
#  Airplane           0
#  Ship               1
#  Name: 1594, dtype: object, File        1607.tif
#  Vehicle            0
#  Airplane           0
#  Ship              55
#  Name: 1607, dtype: object, File        1608.tif
#  Vehicle            0
#  Airplane           0
#  Ship               1
#  Name: 1608, dtype: object, File        1614.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1614, dtype: object, File        1615.tif
#  Vehicle            0
#  Airplane           0
#  Ship              65
#  Name: 1615, dtype: object, File        1618.tif
#  Vehicle            0
#  Airplane           0
#  Ship               6
#  Name: 1618, dtype: object, File        1620.tif
#  Vehicle            0
#  Airplane           0
#  Ship              29
#  Name: 1620, dtype: object, File        1621.tif
#  Vehicle            0
#  Airplane           0
#  Ship              24
#  Name: 1621, dtype: object, File        1629.tif
#  Vehicle            0
#  Airplane           0
#  Ship               6
#  Name: 1629, dtype: object, File        1630.tif
#  Vehicle            0
#  Airplane           0
#  Ship              17
#  Name: 1630, dtype: object, File        1638.tif
#  Vehicle            0
#  Airplane           0
#  Ship              21
#  Name: 1638, dtype: object, File        1640.tif
#  Vehicle            0
#  Airplane           0
#  Ship               4
#  Name: 1640, dtype: object, File        1641.tif
#  Vehicle            0
#  Airplane           0
#  Ship               6
#  Name: 1641, dtype: object, File        1649.tif
#  Vehicle            0
#  Airplane           0
#  Ship               1
#  Name: 1649, dtype: object, File        1654.tif
#  Vehicle            0
#  Airplane           0
#  Ship               6
#  Name: 1654, dtype: object, File        1663.tif
#  Vehicle            0
#  Airplane           0
#  Ship              21
#  Name: 1663, dtype: object, File        1664.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1664, dtype: object, File        1666.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1666, dtype: object, File        1668.tif
#  Vehicle            0
#  Airplane           0
#  Ship               5
#  Name: 1668, dtype: object, File        1672.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1672, dtype: object, File        1677.tif
#  Vehicle            0
#  Airplane           0
#  Ship               5
#  Name: 1677, dtype: object, File        1678.tif
#  Vehicle            0
#  Airplane           0
#  Ship               3
#  Name: 1678, dtype: object, File        1682.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1682, dtype: object, File        1683.tif
#  Vehicle            0
#  Airplane           0
#  Ship               4
#  Name: 1683, dtype: object, File        1684.tif
#  Vehicle            0
#  Airplane           0
#  Ship              20
#  Name: 1684, dtype: object, File        1687.tif
#  Vehicle            0
#  Airplane           0
#  Ship               5
#  Name: 1687, dtype: object, File        1688.tif
#  Vehicle            0
#  Airplane           0
#  Ship               5
#  Name: 1688, dtype: object, File        1691.tif
#  Vehicle            0
#  Airplane           0
#  Ship              45
#  Name: 1691, dtype: object, File        1692.tif
#  Vehicle            0
#  Airplane           0
#  Ship               4
#  Name: 1692, dtype: object, File        1694.tif
#  Vehicle            0
#  Airplane           0
#  Ship              90
#  Name: 1694, dtype: object, File        1697.tif
#  Vehicle            0
#  Airplane           0
#  Ship               5
#  Name: 1697, dtype: object, File        1704.tif
#  Vehicle            0
#  Airplane           0
#  Ship               5
#  Name: 1704, dtype: object, File        1705.tif
#  Vehicle            0
#  Airplane           0
#  Ship               2
#  Name: 1705, dtype: object, File        1711.tif
#  Vehicle            0
#  Airplane           0
#  Ship               3
#  Name: 1711, dtype: object, File        1712.tif
#  Vehicle            0
#  Airplane           0
#  Ship              10
#  Name: 1712, dtype: object, File        1719.tif
#  Vehicle            0
#  Airplane           0
#  Ship              32
#  Name: 1719, dtype: object, File        1723.tif
#  Vehicle            0
#  Airplane           0
#  Ship             196
#  Name: 1723, dtype: object, File        1729.tif
#  Vehicle            0
#  Airplane           0
#  Ship               4
#  Name: 1729, dtype: object, File        1731.tif
#  Vehicle            0
#  Airplane           0
#  Ship               3
#  Name: 1731, dtype: object]

# %%
# train_part1의 결과

# len(only_vehicle) #784
# len(only_ship) #471
len(only_airplane) #376
# Out:
# 376

# %%
# train_part2

for i in range(len(data2)):
  if data2.iloc[i][1] != 0 and data2.iloc[i][2] == 0 and data2.iloc[i][3] ==0 :
    only_vehicle.append(data2.iloc[i])

# %%
for i in range(len(data2)):
  if data2.iloc[i][2] != 0 and data2.iloc[i][1] == 0 and data2.iloc[i][3] ==0 :
    only_airplane.append(data2.iloc[i])

# %%
for i in range(len(data2)):
  if data2.iloc[i][3] != 0 and data2.iloc[i][1] == 0 and data2.iloc[i][2] ==0 :
    only_ship.append(data2.iloc[i])

# %%
# train_part1 + train_part2

# len(only_vehicle) #5947
# len(only_airplane) #5521
len(only_ship) #3947
# Out:
# 3947

# %%
# validation

for i in range(len(data3)):
  if data3.iloc[i][1] != 0 and data3.iloc[i][2] == 0 and data3.iloc[i][3] ==0 :
    only_vehicle.append(data3.iloc[i])

# %%
for i in range(len(data3)):
  if data3.iloc[i][2] != 0 and data3.iloc[i][1] == 0 and data3.iloc[i][3] ==0 :
    only_airplane.append(data3.iloc[i])

# %%
for i in range(len(data3)):
  if data3.iloc[i][3] != 0 and data3.iloc[i][1] == 0 and data3.iloc[i][2] ==0 :
    only_ship.append(data3.iloc[i])

# %%
# train_part1 + train_part2 + validation

# len(only_vehicle) #8739
# len(only_airplane) #10117
len(only_ship) #6201
# Out:
# 6201

# %%
only_vehicle[0]
only_vehicle[3][0]
# Out:
# '21.tif'

# %%
# annotation file 복사하기
# train_super
import os
from os import path
import shutil


origin_path = '/content/drive/MyDrive/Aiffelthon/mmrotate/data/fair1m2.0/train_super'
copy_path = '/content/drive/MyDrive/Aiffelthon/mmrotate/data/fair1m2.0/train_1000_super'

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/Aiffelthon/eda/tif_file_class_frequency

# %%
# %cd /content/drive/MyDrive/Aiffelthon/mmrotate/data/fair1m2.0/train_super
# Out:
# /content/drive/MyDrive/Aiffelthon/mmrotate/data/fair1m2.0/train_super

# %%
files = os.listdir(origin_path)

# %%
files = sorted(files)

# %%
# train_1000_super 복사하기
# files
len(files)
# Out:
# 14194

# %%
files[0]
# Out:
# '10000.txt'

# %%
import os.path

# file_check = only_vehicle[i][0]
print(os.path.isfile(only_vehicle[200][0]))
# Out:
# False

# %%
# origin = origin_path + '/' + str(files[0])
# copy = copy_path + '/' + str(files[0])   #str(only_vehicle[3][0])

# shutil.copy(origin, copy)

# %%
only_vehicle[5][0]#.strip('.tif')
# Out:
# '23.tif'

# %%
# origin = origin_path + '/' + str(files[0])
# copy = copy_path + '/' + str(files[0])

for i in range(len(only_vehicle)):
  origin = origin_path + '/' + str(files[i])
  copy = copy_path + '/' + str(files[i])
  check_vehicle = only_vehicle[i][0].strip('.tif') + str('.txt')
  if os.path.isfile(check_vehicle) :
    # print(files[i])
    shutil.copy(origin, copy)
    # num = num+1
    # print(num)

# %%
# 이제 train_super_vehicle

copy_path2 = '/content/drive/MyDrive/Aiffelthon/mmrotate/data/fair1m2.0/train_super_vehicle'
