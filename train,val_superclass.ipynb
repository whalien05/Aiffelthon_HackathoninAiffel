# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Aiffelthon
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Aiffelthon

# %%
# get_one = train_super_list + [0]

# file = open( train_super_path+[0], "r")
# strings = file.readlines()
# print(strings)
# file.close()

# %% [markdown]
# ### train_part1, train_part2 / validation annotation에서 only_vehicel, only_airplane, only_ship 만을 추출하여 통합된 각각의 파일 만들기
#
# train_super -> only vehicle, airplane, ship
# val_super -> only vehicle, airplane, ship

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Aiffelthon/mmrotate/data/fair1m2.0/train_super'

# %%
# %cd /content/drive/MyDrive/Aiffelthon/eda/tif_file_class_frequency/class_frequencey/
# Out:
# /content/drive/MyDrive/Aiffelthon/eda/tif_file_class_frequency/class_frequencey

# %%
import pandas as pd

data = pd.read_csv("train_part1_tif_class_frequency.csv")
data2 = pd.read_csv("train_part2_tif_class_frequency.csv")
data3 = pd.read_csv("validation_tif_class_frequency.csv")

data.head()
# Out:
#     File  Vehicle  Airplane  Ship
# 0  0.tif        0         0     3
# 1  1.tif       68         0     0
# 2  2.tif        0         3     0
# 3  3.tif        0         0     0
# 4  4.tif        0         2     0

# %%
data3.head()

# %%
# 각 row의 column 마다 접근할 수 있음
data.iloc[1][1]

# .iloc[i][1]=vehicle, .iloc[i][2]=airplane, .iloc[i][1]=ship
# len(data)=1731
# Out:
# 68

# %%
only_vehicle = [] 
only_airplane=[]
only_ship=[]

# %% [markdown]
# #### data(train part1)을 only_vehicle/only_airplane/only_ship으로 나눔

# %%
for i in range(len(data)):
  if data.iloc[i][1] != 0 and data.iloc[i][2] == 0 and data.iloc[i][3] ==0 :
    only_vehicle.append(data.iloc[i])
# break

# %%
for i in range(len(data)):
  if data.iloc[i][2] != 0 and data.iloc[i][1] == 0 and data.iloc[i][3] ==0 :
    only_airplane.append(data.iloc[i])

# %%
for i in range(len(data)):
  if data.iloc[i][3] != 0 and data.iloc[i][1] == 0 and data.iloc[i][2] ==0 :
    only_ship.append(data.iloc[i])

# %%
only_vehicle[:10]
# Out:
# [File        1.tif
#  Vehicle        68
#  Airplane        0
#  Ship            0
#  Name: 1, dtype: object, File        8.tif
#  Vehicle       118
#  Airplane        0
#  Ship            0
#  Name: 8, dtype: object, File        18.tif
#  Vehicle         87
#  Airplane         0
#  Ship             0
#  Name: 18, dtype: object, File        21.tif
#  Vehicle         56
#  Airplane         0
#  Ship             0
#  Name: 21, dtype: object, File        22.tif
#  Vehicle         49
#  Airplane         0
#  Ship             0
#  Name: 22, dtype: object, File        23.tif
#  Vehicle        162
#  Airplane         0
#  Ship             0
#  Name: 23, dtype: object, File        24.tif
#  Vehicle         13
#  Airplane         0
#  Ship             0
#  Name: 24, dtype: object, File        25.tif
#  Vehicle         60
#  Airplane         0
#  Ship             0
#  Name: 25, dtype: object, File        26.tif
#  Vehicle        108
#  Airplane         0
#  Ship             0
# ...

# %%
only_airplane[:5]

# %%
only_ship[:5]

# %%
# train_part1의 결과

# len(only_vehicle) #784
# len(only_ship) #471
len(only_airplane) #376
# Out:
# 376

# %% [markdown]
# #### data2(train part2)을 only_vehicle/only_airplane/only_ship으로 나눔

# %%
# train_part2

for i in range(len(data2)):
  if data2.iloc[i][1] != 0 and data2.iloc[i][2] == 0 and data2.iloc[i][3] ==0 :
    only_vehicle.append(data2.iloc[i])

# %%
for i in range(len(data2)):
  if data2.iloc[i][2] != 0 and data2.iloc[i][1] == 0 and data2.iloc[i][3] ==0 :
    only_airplane.append(data2.iloc[i])

# %%
for i in range(len(data2)):
  if data2.iloc[i][3] != 0 and data2.iloc[i][1] == 0 and data2.iloc[i][2] ==0 :
    only_ship.append(data2.iloc[i])

# %%
# train_part1 + train_part2

# len(only_vehicle) #5947
# len(only_airplane) #5521
len(only_ship) #3947
# Out:
# 3947

# %% [markdown]
# #### data3(validation)을 only_vehicle_val/only_airplane_val/only_ship_val으로 나눔

# %%
only_vehicle_val = []
only_airplane_val = []
only_ship_val = []

# %%
for i in range(len(data3)):
  if data3.iloc[i][1] != 0 and data3.iloc[i][2] == 0 and data3.iloc[i][3] ==0 :
    only_vehicle_val.append(data3.iloc[i])

# %%
for i in range(len(data3)):
  if data3.iloc[i][2] != 0 and data3.iloc[i][1] == 0 and data3.iloc[i][3] ==0 :
    only_airplane_val.append(data3.iloc[i])

# %%
for i in range(len(data3)):
  if data3.iloc[i][3] != 0 and data3.iloc[i][1] == 0 and data3.iloc[i][2] ==0 :
    only_ship_val.append(data3.iloc[i])

# %%
# validation

len(only_vehicle_val) #2792
# len(only_airplane_val) #2298
# len(only_ship_val) #2254
# Out:
# 2792

# %%
only_vehicle_val[:10]
# Out:
# [File        1.tif
#  Vehicle        20
#  Airplane        0
#  Ship            0
#  Name: 1, dtype: object, File        4.tif
#  Vehicle        44
#  Airplane        0
#  Ship            0
#  Name: 4, dtype: object, File        6.tif
#  Vehicle        19
#  Airplane        0
#  Ship            0
#  Name: 6, dtype: object, File        7.tif
#  Vehicle        20
#  Airplane        0
#  Ship            0
#  Name: 7, dtype: object, File        10.tif
#  Vehicle         14
#  Airplane         0
#  Ship             0
#  Name: 10, dtype: object, File        15.tif
#  Vehicle        116
#  Airplane         0
#  Ship             0
#  Name: 15, dtype: object, File        16.tif
#  Vehicle         34
#  Airplane         0
#  Ship             0
#  Name: 16, dtype: object, File        17.tif
#  Vehicle         31
#  Airplane         0
#  Ship             0
#  Name: 17, dtype: object, File        19.tif
#  Vehicle         65
#  Airplane         0
#  Ship             0
# ...

# %% [markdown]
# ## only_vehicle/airplane/ship list을 원본 데이터(train_super)에서 train_super_vehicle/train_super_airplane/train_super_ship의 파일로 복사하기

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Aiffelthon/eda/tif_file_class_frequency/class_frequencey'

# %%
# %cd /content/drive/MyDrive/Aiffelthon/mmrotate/data/fair1m2.0/train_super
# Out:
# /content/drive/MyDrive/Aiffelthon/mmrotate/data/fair1m2.0/train_super

# %% [markdown]
# ### only_vehicle을 train_super_vehicle으로

# %%
# train_super(원본 annotation file)에서 복사할 파일로 경로 설정

import os
from os import path
import shutil
import os.path


origin_path = '/content/drive/MyDrive/Aiffelthon/mmrotate/data/fair1m2.0/train_super'
copy_path1 = '/content/drive/MyDrive/Aiffelthon/mmrotate/data/fair1m2.0/train_super_vehicle'

# %%
origin_files = os.listdir(origin_path)

# %%
# origin_files = sorted(origin_files)

# %%
len(origin_files)
# Out:
# 15920

# %%
# only_vehicle과 원본 파일 이름 다름(.tif, .txt)
only_vehicle[1][0], origin_files[0]
# Out:
# ('8.tif', '15454.txt')

# %%
  # only_vehicle list 확인차
  only_vehicle[1][0] #= 8.tif

# only_vehicle list에 들어있는 파일이름들은 모두 '숫자.tif'으로 되어있으므로, 원본 annotation file에 접근하려면
# '숫자.txt'으로 변환하는 과정을 거쳐야.

  check_vehicle1 = only_vehicle[1][0].strip('.tif') + str('.txt')
  check_vehicle1 #= 8.txt
# Out:
# '8.txt'

# %%
# os.path.isfile 함수 사용해서 only_vehicle list에 있는 해당 파일이 원본 annotation 파일에 있는지 확인(항상 true일 것이어야 한다)

check_vehicle1
print(os.path.isfile(check_vehicle1)) # ?! -> 수정 후 정상화(True)
# Out:
# True

# %%
# only_vehicle 목록에 있는 원본 파일
# origin = origin_path + '/' + str(check_vehicle1)

# 복사할 파일(원본파일과 이름 동일하게, 저장될 파일 경로만 변경)
copy = copy_path1 + '/' + str(check_vehicle1)   #str(only_vehicle[3][0])

print('원본 파일이 있는곳: '+ origin,'\n','복사할 경로: '+copy)

# shutil.copy(origin, copy)
# Out:
# 원본 파일이 있는곳: /content/drive/MyDrive/Aiffelthon/mmrotate/data/fair1m2.0/train_super/8.txt
#  복사할 경로: /content/drive/MyDrive/Aiffelthon/mmrotate/data/fair1m2.0/train_super_vehicle/8.txt

# %%
only_vehicle[5][0]#.strip('.tif')
# Out:
# '23.tif'

# %%
for i in range(len(only_vehicle)):
  change_name = only_vehicle[i][0].strip('.tif') + str('.txt')
  origin_file = origin_path + '/' + str(change_name)
  copy_file = copy_path1 + '/' + str(change_name)
  if os.path.isfile(change_name):
      shutil.copy(origin_file, copy_file)

# %% [markdown]
# ### only_airplane을 train_super_airplane으로

# %%
copy_path2 = '/content/drive/MyDrive/Aiffelthon/mmrotate/data/fair1m2.0/train_super_airplane'

# %%
for i in range(len(only_airplane)):
  change_name = only_airplane[i][0].strip('.tif') + str('.txt')
  origin_file = origin_path + '/' + str(change_name)
  copy_file = copy_path2 + '/' + str(change_name)
  if os.path.isfile(change_name):
      shutil.copy(origin_file, copy_file)

# %% [markdown]
# ### only_ship을 train_super_ship으로

# %%
copy_path3 = '/content/drive/MyDrive/Aiffelthon/mmrotate/data/fair1m2.0/train_super_ship'

# %%
for i in range(len(only_ship)):
  change_name = only_ship[i][0].strip('.tif') + str('.txt')
  origin_file = origin_path + '/' + str(change_name)
  copy_file = copy_path3 + '/' + str(change_name)
  if os.path.isfile(change_name):
      shutil.copy(origin_file, copy_file)

# %% [markdown]
# ## only_vehicle/airplane/ship_val list을 원본 데이터(val_super)에서 2/3 정도만 val_super_vehicle/val_super_airplane/val_super_ship의 파일로 복사하기

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Aiffelthon/mmrotate/data/fair1m2.0/train_super'

# %%
# %cd /content/drive/MyDrive/Aiffelthon/mmrotate/data/fair1m2.0/val_super
# Out:
# /content/drive/MyDrive/Aiffelthon/mmrotate/data/fair1m2.0/val_super

# %% [markdown]
# ### only_vehicle_val을 val_super_vehicle으로

# %%
# val_super(원본 annotation file)에서 복사할 파일로 경로 설정

origin_val_path = '/content/drive/MyDrive/Aiffelthon/mmrotate/data/fair1m2.0/val_super'
copy_val_path1 = '/content/drive/MyDrive/Aiffelthon/mmrotate/data/fair1m2.0/val_super_vehicle'

# %%
origin_val_files = os.listdir(origin_val_path)

# %%
len(origin_val_files)
# Out:
# 5094

# %%
# only_vehicle과 원본 파일 이름 다름(.tif, .txt)
# only_vehicle_val[1][0], origin_val_files[0]

# %%
for i in range(len(only_vehicle_val)):
  change_name = only_vehicle_val[i][0].strip('.tif') + str('.txt')
  origin_file = origin_val_path + '/' + str(change_name)
  copy_file = copy_val_path1 + '/' + str(change_name)
  if os.path.isfile(change_name):
      shutil.copy(origin_file, copy_file)

# %% [markdown]
# ### only_airplane을 val_super_airplane으로

# %%
copy_val_path2 = '/content/drive/MyDrive/Aiffelthon/mmrotate/data/fair1m2.0/val_super_airplane'

# %%
for i in range(len(only_airplane_val)):
  change_name = only_airplane_val[i][0].strip('.tif') + str('.txt')
  origin_file = origin_val_path + '/' + str(change_name)
  copy_file = copy_val_path2 + '/' + str(change_name)
  if os.path.isfile(change_name):
      shutil.copy(origin_file, copy_file)

# %% [markdown]
# ### only_ship을 val_super_ship으로

# %%
copy_val_path3 = '/content/drive/MyDrive/Aiffelthon/mmrotate/data/fair1m2.0/val_super_ship'

# %%
for i in range(len(only_ship_val)):
  change_name = only_ship_val[i][0].strip('.tif') + str('.txt')
  origin_file = origin_val_path + '/' + str(change_name)
  copy_file = copy_val_path3 + '/' + str(change_name)
  if os.path.isfile(change_name):
      shutil.copy(origin_file, copy_file)
